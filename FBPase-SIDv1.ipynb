# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
import scipy.stats as stats
import glob

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning) #this was relevant for the String-boolean Int-boolean comparison in the Residue vs Atom double filtering below (god I miss SQL...)

# %%
# My poor less fancy importing scheme for multiple files =P
wrkdir = 'C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Results' #You have to define where the folders and subfolder will be
os.chdir(wrkdir)
name="Arg159_188" #change here the name of the system, so it can pick all the files automatically

#Those features are stratified with the number of residue only
hydrophobic=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Arg159_188\\PL-Contacts_Hydrophobic.dat'.format(wrkdir, name), sep='\s+')
ionic=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Arg159_188\\PL-Contacts_Ionic.dat'.format(wrkdir, name), sep='\s+')

#Those features need the number of residue and atom for proper separation
pipi=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Arg159_188\\PL-Contacts_Pi-Pi.dat'.format(wrkdir, name), sep='\s+')
hbond=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Arg159_188\\PL-Contacts_HBond.dat'.format(wrkdir, name), sep='\s+')
water=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Arg159_188\\PL-Contacts_WaterBridge.dat'.format(wrkdir, name), sep='\s+')

# %%
#HYDROGEN BOND INTERACTIONS
hbond_unique=hbond.drop_duplicates(['Residue','AtomName'])
hbond_unique = hbond_unique.reset_index(drop=True)
hbond_db = [{'Type':0,'ResName':0,'Residue':0, 'AtomName':0,'Frequency':0}] #I setup an interaction Type variable for later help with the plotting
x=0
while x<hbond_unique["Residue"].size:
    
    freq = np.sum((hbond["Residue"]==hbond_unique["Residue"][x])|(hbond["AtomName"]==hbond_unique["AtomName"][x]))/(hbond["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"hbond",'ResName':hbond_unique["ResName"][x],'Residue':hbond_unique["Residue"][x],'AtomName':hbond_unique["AtomName"][x], 'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        hbond_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
    
print("hydrogen bond by Residue and AtomName number")
hbond_df=pd.DataFrame(hbond_db)
hbond_df=hbond_df.loc[~(hbond_df==0).all(axis=1)]
print(pd.DataFrame(hbond_df))

#HYDROPHOBIC INTERACTIONS DEFINITIONS
hydrophobic_unique=hydrophobic.drop_duplicates(['Residue'])
hydrophobic_unique = hydrophobic_unique.reset_index(drop=True)
hydrophobic_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<hydrophobic_unique["Residue"].size:
    freq = np.sum((hydrophobic["Residue"]==hydrophobic_unique["Residue"][x]))/(hydrophobic["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"hydrophobic",'ResName':hydrophobic_unique["ResName"][x],'Residue':hydrophobic_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        hydrophobic_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("Hydrophobic interactions by Residue number")
hydrophobic_df=pd.DataFrame(hydrophobic_db)
hydrophobic_df=hydrophobic_df.loc[~(hydrophobic_df==0).all(axis=1)]
print(pd.DataFrame(hydrophobic_df))

#IONIC INTERACTIONS
ionic_unique=ionic.drop_duplicates(['Residue'])
ionic_unique = ionic_unique.reset_index(drop=True)
ionic_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<ionic_unique["Residue"].size:
    freq = np.sum((ionic["Residue"]==ionic_unique["Residue"][x]))/(ionic["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"ionic",'ResName':ionic_unique["ResName"][x],'Residue':ionic_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        ionic_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("Ionic interactions by Residue number")
ionic_df=pd.DataFrame(ionic_db)
ionic_df=ionic_df.loc[~(ionic_df==0).all(axis=1)]
print(pd.DataFrame(ionic_df))

#PI-PI INTERACTIONS
pipi_unique=pipi.drop_duplicates(['Residue'])
pipi_unique = pipi_unique.reset_index(drop=True)
pipi_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<pipi_unique["Residue"].size:
    freq = np.sum((pipi["Residue"]==pipi_unique["Residue"][x]))/(pipi["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"pi-pi",'ResName':pipi_unique["ResName"][x],'Residue':pipi_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        pipi_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("pi-pi interactions by Residue number")
pipi_df=pd.DataFrame(pipi_db)
pipi_df=pipi_df.loc[~(pipi_df==0).all(axis=1)]
print(pd.DataFrame(pipi_df))

#WATER INTERACTIONS
water_unique=water.drop_duplicates(['Residue'])
water_unique = water_unique.reset_index(drop=True)
water_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<water_unique["Residue"].size:
    freq = np.sum((water["Residue"]==water_unique["Residue"][x]))/(water["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"water",'ResName':water_unique["ResName"][x],'Residue':water_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        water_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("water-mediated interactions by Residue number")
water_df=pd.DataFrame(water_db)
water_df=water_df.loc[~(water_df==0).all(axis=1)]
print(pd.DataFrame(water_df))
# Out:
# hydrogen bond by Residue and AtomName number
#      Type ResName  Residue AtomName  Frequency
# 1   hbond     THR      180        O  51.177024
# 2   hbond     ASP      158        O  51.177024
# 3   hbond     ASP      181      OD1  24.529190
# 4   hbond     HIS      162        H  23.846516
# 5   hbond     LEU      157        O  51.177024
# 6   hbond     GLY       83        H  23.846516
# 7   hbond     SER       84        H  23.846516
# 8   hbond     ASP      181      OD2  24.505650
# 9   hbond     ASP       70      OD2  10.734463
# 10  hbond     GLY      104        O  51.177024
# 11  hbond     ASP       27      OD2  10.710923
# 12  hbond     LEU      272        O  51.177024
# 13  hbond     ASP      151        O  51.177024
# 14  hbond     ASP      108      OD1  13.912429
# 15  hbond     ALA      163        H  23.846516
# 16  hbond     GLY       90        O  51.177024
# 17  hbond     ALA       13        O  51.177024
# 18  hbond     PHE      113        H  23.846516
# 19  hbond     ASP      231      OD1  13.912429
# 20  hbond     TYR      303        O  51.177024
# 21  hbond     ASP      271      OD2  10.710923
# 22  hbond     VAL       48        O  51.177024
# 23  hbond     ASP      244        O  51.177024
# 24  hbond     ASP      168      OD2  10.710923
# 25  hbond     ASP       70      OD1  13.935970
# Hydrophobic interactions by Residue number
#           Type ResName  Residue  Frequency
# 1  hydrophobic     PRO      160  96.727623
# Ionic interactions by Residue number
# Empty DataFrame
# Columns: [Type, ResName, Residue, Frequency]
# Index: []
# pi-pi interactions by Residue number
# Empty DataFrame
# Columns: [Type, ResName, Residue, Frequency]
# Index: []
# water-mediated interactions by Residue number
#     Type ResName  Residue  Frequency
# 1  water     ASP      158  47.096774

# %%
#In case you want to have different styles : https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
frames = pd.concat([hbond_df,water_df,hydrophobic_df,ionic_df,pipi_df])
#frames.to_csv('interactions.tsv', sep = '\t')
print(frames)
frames.to_csv('interactions_{}.tsv'.format(name), sep='\t')
# Out:
#            Type ResName  Residue AtomName  Frequency
# 1         hbond     THR      180        O  51.177024
# 2         hbond     ASP      158        O  51.177024
# 3         hbond     ASP      181      OD1  24.529190
# 4         hbond     HIS      162        H  23.846516
# 5         hbond     LEU      157        O  51.177024
# 6         hbond     GLY       83        H  23.846516
# 7         hbond     SER       84        H  23.846516
# 8         hbond     ASP      181      OD2  24.505650
# 9         hbond     ASP       70      OD2  10.734463
# 10        hbond     GLY      104        O  51.177024
# 11        hbond     ASP       27      OD2  10.710923
# 12        hbond     LEU      272        O  51.177024
# 13        hbond     ASP      151        O  51.177024
# 14        hbond     ASP      108      OD1  13.912429
# 15        hbond     ALA      163        H  23.846516
# 16        hbond     GLY       90        O  51.177024
# 17        hbond     ALA       13        O  51.177024
# 18        hbond     PHE      113        H  23.846516
# 19        hbond     ASP      231      OD1  13.912429
# 20        hbond     TYR      303        O  51.177024
# 21        hbond     ASP      271      OD2  10.710923
# 22        hbond     VAL       48        O  51.177024
# 23        hbond     ASP      244        O  51.177024
# 24        hbond     ASP      168      OD2  10.710923
# 25        hbond     ASP       70      OD1  13.935970
# 1         water     ASP      158      NaN  47.096774
# 1   hydrophobic     PRO      160      NaN  96.727623

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
import scipy.stats as stats
import glob

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning) #this was relevant for the String-boolean Int-boolean comparison in the Residue vs Atom double filtering below (god I miss SQL...)

# %%
# My poor less fancy importing scheme for multiple files =P
wrkdir = 'C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Results' #You have to define where the folders and subfolder will be
os.chdir(wrkdir)
name="Arg159_189" #change here the name of the system, so it can pick all the files automatically

#Those features are stratified with the number of residue only
hydrophobic=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Gln159_189\\PL-Contacts_Hydrophobic.dat'.format(wrkdir, name), sep='\s+')
ionic=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Gln159_189\\PL-Contacts_Ionic.dat'.format(wrkdir, name), sep='\s+')

#Those features need the number of residue and atom for proper separation
pipi=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Gln159_189\\PL-Contacts_Pi-Pi.dat'.format(wrkdir, name), sep='\s+')
hbond=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Gln159_189\\PL-Contacts_HBond.dat'.format(wrkdir, name), sep='\s+')
water=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Gln159_189\\PL-Contacts_WaterBridge.dat'.format(wrkdir, name), sep='\s+')

# %%
#HYDROGEN BOND INTERACTIONS
hbond_unique=hbond.drop_duplicates(['Residue','AtomName'])
hbond_unique = hbond_unique.reset_index(drop=True)
hbond_db = [{'Type':0,'ResName':0,'Residue':0, 'AtomName':0,'Frequency':0}] #I setup an interaction Type variable for later help with the plotting
x=0
while x<hbond_unique["Residue"].size:
    
    freq = np.sum((hbond["Residue"]==hbond_unique["Residue"][x])|(hbond["AtomName"]==hbond_unique["AtomName"][x]))/(hbond["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"hbond",'ResName':hbond_unique["ResName"][x],'Residue':hbond_unique["Residue"][x],'AtomName':hbond_unique["AtomName"][x], 'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        hbond_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
    
print("hydrogen bond by Residue and AtomName number")
hbond_df=pd.DataFrame(hbond_db)
hbond_df=hbond_df.loc[~(hbond_df==0).all(axis=1)]
print(pd.DataFrame(hbond_df))

#HYDROPHOBIC INTERACTIONS DEFINITIONS
hydrophobic_unique=hydrophobic.drop_duplicates(['Residue'])
hydrophobic_unique = hydrophobic_unique.reset_index(drop=True)
hydrophobic_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<hydrophobic_unique["Residue"].size:
    freq = np.sum((hydrophobic["Residue"]==hydrophobic_unique["Residue"][x]))/(hydrophobic["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"hydrophobic",'ResName':hydrophobic_unique["ResName"][x],'Residue':hydrophobic_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        hydrophobic_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("Hydrophobic interactions by Residue number")
hydrophobic_df=pd.DataFrame(hydrophobic_db)
hydrophobic_df=hydrophobic_df.loc[~(hydrophobic_df==0).all(axis=1)]
print(pd.DataFrame(hydrophobic_df))

#IONIC INTERACTIONS
ionic_unique=ionic.drop_duplicates(['Residue'])
ionic_unique = ionic_unique.reset_index(drop=True)
ionic_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<ionic_unique["Residue"].size:
    freq = np.sum((ionic["Residue"]==ionic_unique["Residue"][x]))/(ionic["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"ionic",'ResName':ionic_unique["ResName"][x],'Residue':ionic_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        ionic_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("Ionic interactions by Residue number")
ionic_df=pd.DataFrame(ionic_db)
ionic_df=ionic_df.loc[~(ionic_df==0).all(axis=1)]
print(pd.DataFrame(ionic_df))

#PI-PI INTERACTIONS
pipi_unique=pipi.drop_duplicates(['Residue'])
pipi_unique = pipi_unique.reset_index(drop=True)
pipi_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<pipi_unique["Residue"].size:
    freq = np.sum((pipi["Residue"]==pipi_unique["Residue"][x]))/(pipi["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"pi-pi",'ResName':pipi_unique["ResName"][x],'Residue':pipi_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        pipi_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("pi-pi interactions by Residue number")
pipi_df=pd.DataFrame(pipi_db)
pipi_df=pipi_df.loc[~(pipi_df==0).all(axis=1)]
print(pd.DataFrame(pipi_df))

#WATER INTERACTIONS
water_unique=water.drop_duplicates(['Residue'])
water_unique = water_unique.reset_index(drop=True)
water_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<water_unique["Residue"].size:
    freq = np.sum((water["Residue"]==water_unique["Residue"][x]))/(water["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"water",'ResName':water_unique["ResName"][x],'Residue':water_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        water_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("water-mediated interactions by Residue number")
water_df=pd.DataFrame(water_db)
water_df=water_df.loc[~(water_df==0).all(axis=1)]
print(pd.DataFrame(water_df))
# Out:
# hydrogen bond by Residue and AtomName number
#      Type ResName  Residue AtomName  Frequency
# 1   hbond     THR      180        O  49.508747
# 2   hbond     ASP      158        O  49.508747
# 3   hbond     ASP      181      OD1  26.000479
# 4   hbond     HIS      162        H  24.083393
# 5   hbond     LEU      157        O  49.508747
# 6   hbond     ASP      168      OD1  10.855500
# 7   hbond     ASP      181      OD2  25.904625
# 8   hbond     ASP       70      OD1  10.879463
# 9   hbond     ASN       68        O  49.508747
# 10  hbond     GLY       21        H  24.083393
# 11  hbond     ASP      102      OD2  15.168943
# 12  hbond     ASN      259        H  24.107357
# 13  hbond     ARG      139        O  49.532710
# 14  hbond     ASP       70        O  49.556674
# 15  hbond     ASN      246      OD1  10.855500
# 16  hbond     ASN      259      OD1  10.879463
# 17  hbond     LEU      128        O  49.508747
# 18  hbond     ASP      108        H  24.083393
# 19  hbond     GLY      242        O  49.508747
# 20  hbond     ARG      161        H  24.083393
# 21  hbond     GLY       50        O  49.508747
# 22  hbond     GLY      173        O  49.508747
# Hydrophobic interactions by Residue number
#           Type ResName  Residue  Frequency
# 1  hydrophobic     PRO      160  94.811321
# Ionic interactions by Residue number
#     Type ResName  Residue  Frequency
# 1  ionic     ASP      181      112.5
# pi-pi interactions by Residue number
# Empty DataFrame
# Columns: [Type, ResName, Residue, Frequency]
# Index: []
# water-mediated interactions by Residue number
#     Type ResName  Residue  Frequency
# 1  water     ASP      158  49.268293
# 2  water     THR      180  10.243902

# %%
#In case you want to have different styles : https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
frames = pd.concat([hbond_df,water_df,hydrophobic_df,ionic_df,pipi_df])
#frames.to_csv('interactions.tsv', sep = '\t')
print(frames)
frames.to_csv('interactions_{}.tsv'.format(name), sep='\t')
# Out:
#            Type ResName  Residue AtomName   Frequency
# 1         hbond     THR      180        O   49.508747
# 2         hbond     ASP      158        O   49.508747
# 3         hbond     ASP      181      OD1   26.000479
# 4         hbond     HIS      162        H   24.083393
# 5         hbond     LEU      157        O   49.508747
# 6         hbond     ASP      168      OD1   10.855500
# 7         hbond     ASP      181      OD2   25.904625
# 8         hbond     ASP       70      OD1   10.879463
# 9         hbond     ASN       68        O   49.508747
# 10        hbond     GLY       21        H   24.083393
# 11        hbond     ASP      102      OD2   15.168943
# 12        hbond     ASN      259        H   24.107357
# 13        hbond     ARG      139        O   49.532710
# 14        hbond     ASP       70        O   49.556674
# 15        hbond     ASN      246      OD1   10.855500
# 16        hbond     ASN      259      OD1   10.879463
# 17        hbond     LEU      128        O   49.508747
# 18        hbond     ASP      108        H   24.083393
# 19        hbond     GLY      242        O   49.508747
# 20        hbond     ARG      161        H   24.083393
# 21        hbond     GLY       50        O   49.508747
# 22        hbond     GLY      173        O   49.508747
# 1         water     ASP      158      NaN   49.268293
# 2         water     THR      180      NaN   10.243902
# 1   hydrophobic     PRO      160      NaN   94.811321
# 1         ionic     ASP      181      NaN  112.500000

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
import scipy.stats as stats
import glob

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning) #this was relevant for the String-boolean Int-boolean comparison in the Residue vs Atom double filtering below (god I miss SQL...)

# %%
# My poor less fancy importing scheme for multiple files =P START HERE
wrkdir = 'C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Results' #You have to define where the folders and subfolder will be
os.chdir(wrkdir)
name="Arg161_188" #change here the name of the system, so it can pick all the files automatically

#Those features are stratified with the number of residue only
hydrophobic=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Arg161_188\\PL-Contacts_Hydrophobic.dat'.format(wrkdir, name), sep='\s+')
ionic=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Arg161_188\\PL-Contacts_Ionic.dat'.format(wrkdir, name), sep='\s+')

#Those features need the number of residue and atom for proper separation
pipi=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Arg161_188\\PL-Contacts_Pi-Pi.dat'.format(wrkdir, name), sep='\s+')
hbond=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Arg161_188\\PL-Contacts_HBond.dat'.format(wrkdir, name), sep='\s+')
water=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Arg161_188\\PL-Contacts_WaterBridge.dat'.format(wrkdir, name), sep='\s+')

# %%
#HYDROGEN BOND INTERACTIONS
hbond_unique=hbond.drop_duplicates(['Residue','AtomName'])
hbond_unique = hbond_unique.reset_index(drop=True)
hbond_db = [{'Type':0,'ResName':0,'Residue':0, 'AtomName':0,'Frequency':0}] #I setup an interaction Type variable for later help with the plotting
x=0
while x<hbond_unique["Residue"].size:
    
    freq = np.sum((hbond["Residue"]==hbond_unique["Residue"][x])|(hbond["AtomName"]==hbond_unique["AtomName"][x]))/(hbond["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"hbond",'ResName':hbond_unique["ResName"][x],'Residue':hbond_unique["Residue"][x],'AtomName':hbond_unique["AtomName"][x], 'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        hbond_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
    
print("hydrogen bond by Residue and AtomName number")
hbond_df=pd.DataFrame(hbond_db)
hbond_df=hbond_df.loc[~(hbond_df==0).all(axis=1)]
print(pd.DataFrame(hbond_df))

#HYDROPHOBIC INTERACTIONS DEFINITIONS
hydrophobic_unique=hydrophobic.drop_duplicates(['Residue'])
hydrophobic_unique = hydrophobic_unique.reset_index(drop=True)
hydrophobic_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<hydrophobic_unique["Residue"].size:
    freq = np.sum((hydrophobic["Residue"]==hydrophobic_unique["Residue"][x]))/(hydrophobic["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"hydrophobic",'ResName':hydrophobic_unique["ResName"][x],'Residue':hydrophobic_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        hydrophobic_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("Hydrophobic interactions by Residue number")
hydrophobic_df=pd.DataFrame(hydrophobic_db)
hydrophobic_df=hydrophobic_df.loc[~(hydrophobic_df==0).all(axis=1)]
print(pd.DataFrame(hydrophobic_df))

#IONIC INTERACTIONS
ionic_unique=ionic.drop_duplicates(['Residue'])
ionic_unique = ionic_unique.reset_index(drop=True)
ionic_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<ionic_unique["Residue"].size:
    freq = np.sum((ionic["Residue"]==ionic_unique["Residue"][x]))/(ionic["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"ionic",'ResName':ionic_unique["ResName"][x],'Residue':ionic_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        ionic_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("Ionic interactions by Residue number")
ionic_df=pd.DataFrame(ionic_db)
ionic_df=ionic_df.loc[~(ionic_df==0).all(axis=1)]
print(pd.DataFrame(ionic_df))

#PI-PI INTERACTIONS
pipi_unique=pipi.drop_duplicates(['Residue'])
pipi_unique = pipi_unique.reset_index(drop=True)
pipi_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<pipi_unique["Residue"].size:
    freq = np.sum((pipi["Residue"]==pipi_unique["Residue"][x]))/(pipi["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"pi-pi",'ResName':pipi_unique["ResName"][x],'Residue':pipi_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        pipi_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("pi-pi interactions by Residue number")
pipi_df=pd.DataFrame(pipi_db)
pipi_df=pipi_df.loc[~(pipi_df==0).all(axis=1)]
print(pd.DataFrame(pipi_df))

#WATER INTERACTIONS
water_unique=water.drop_duplicates(['Residue'])
water_unique = water_unique.reset_index(drop=True)
water_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<water_unique["Residue"].size:
    freq = np.sum((water["Residue"]==water_unique["Residue"][x]))/(water["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"water",'ResName':water_unique["ResName"][x],'Residue':water_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        water_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("water-mediated interactions by Residue number")
water_df=pd.DataFrame(water_db)
water_df=water_df.loc[~(water_df==0).all(axis=1)]
print(pd.DataFrame(water_df))
# Out:
# hydrogen bond by Residue and AtomName number
#      Type ResName  Residue AtomName  Frequency
# 1   hbond     HIS      162      NE2  34.051724
# 2   hbond     ILE      203        O  50.822884
# 3   hbond     ARG      103        O  50.822884
# 4   hbond     SER      294        O  50.822884
# 5   hbond     GLN      164     HE22  14.380878
# 6   hbond     MET      219        O  50.822884
# 7   hbond     LEU       37        O  50.822884
# 8   hbond     GLN      164     HE21  14.380878
# 9   hbond     VAL      100        O  50.822884
# 10  hbond     HIS      126        O  50.822884
# 11  hbond     LEU      128        O  50.822884
# 12  hbond     PRO      160        O  50.822884
# 13  hbond     LYS       89        O  50.822884
# 14  hbond     ASP      158        O  50.901254
# Hydrophobic interactions by Residue number
#           Type ResName  Residue  Frequency
# 1  hydrophobic     TYR      114  82.758621
# 2  hydrophobic     ILE      203  20.689655
# Ionic interactions by Residue number
# Empty DataFrame
# Columns: [Type, ResName, Residue, Frequency]
# Index: []
# pi-pi interactions by Residue number
# Empty DataFrame
# Columns: [Type, ResName, Residue, Frequency]
# Index: []
# water-mediated interactions by Residue number
#     Type ResName  Residue  Frequency
# 1  water     LEU      165  17.708333
# 2  water     GLN      164  67.500000

# %%
#In case you want to have different styles : https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
frames = pd.concat([hbond_df,water_df,hydrophobic_df,ionic_df,pipi_df])
#frames.to_csv('interactions.tsv', sep = '\t')
print(frames)
frames.to_csv('interactions_{}.tsv'.format(name), sep='\t')
# Out:
#            Type ResName  Residue AtomName  Frequency
# 1         hbond     HIS      162      NE2  34.051724
# 2         hbond     ILE      203        O  50.822884
# 3         hbond     ARG      103        O  50.822884
# 4         hbond     SER      294        O  50.822884
# 5         hbond     GLN      164     HE22  14.380878
# 6         hbond     MET      219        O  50.822884
# 7         hbond     LEU       37        O  50.822884
# 8         hbond     GLN      164     HE21  14.380878
# 9         hbond     VAL      100        O  50.822884
# 10        hbond     HIS      126        O  50.822884
# 11        hbond     LEU      128        O  50.822884
# 12        hbond     PRO      160        O  50.822884
# 13        hbond     LYS       89        O  50.822884
# 14        hbond     ASP      158        O  50.901254
# 1         water     LEU      165      NaN  17.708333
# 2         water     GLN      164      NaN  67.500000
# 1   hydrophobic     TYR      114      NaN  82.758621
# 2   hydrophobic     ILE      203      NaN  20.689655

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
import scipy.stats as stats
import glob

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning) #this was relevant for the String-boolean Int-boolean comparison in the Residue vs Atom double filtering below (god I miss SQL...)

# %%
# My poor less fancy importing scheme for multiple files =P
wrkdir = 'C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Results' #You have to define where the folders and subfolder will be
os.chdir(wrkdir)
name="Arg161_189" #change here the name of the system, so it can pick all the files automatically

#Those features are stratified with the number of residue only
hydrophobic=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Arg161_189\\PL-Contacts_Hydrophobic.dat'.format(wrkdir, name), sep='\s+')
ionic=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Arg161_189\\PL-Contacts_Ionic.dat'.format(wrkdir, name), sep='\s+')

#Those features need the number of residue and atom for proper separation
pipi=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Arg161_189\\PL-Contacts_Pi-Pi.dat'.format(wrkdir, name), sep='\s+')
hbond=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Arg161_189\\PL-Contacts_HBond.dat'.format(wrkdir, name), sep='\s+')
water=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Arg161_189\\PL-Contacts_WaterBridge.dat'.format(wrkdir, name), sep='\s+')

# %%
#HYDROGEN BOND INTERACTIONS
hbond_unique=hbond.drop_duplicates(['Residue','AtomName'])
hbond_unique = hbond_unique.reset_index(drop=True)
hbond_db = [{'Type':0,'ResName':0,'Residue':0, 'AtomName':0,'Frequency':0}] #I setup an interaction Type variable for later help with the plotting
x=0
while x<hbond_unique["Residue"].size:
    
    freq = np.sum((hbond["Residue"]==hbond_unique["Residue"][x])|(hbond["AtomName"]==hbond_unique["AtomName"][x]))/(hbond["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"hbond",'ResName':hbond_unique["ResName"][x],'Residue':hbond_unique["Residue"][x],'AtomName':hbond_unique["AtomName"][x], 'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        hbond_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
    
print("hydrogen bond by Residue and AtomName number")
hbond_df=pd.DataFrame(hbond_db)
hbond_df=hbond_df.loc[~(hbond_df==0).all(axis=1)]
print(pd.DataFrame(hbond_df))

#HYDROPHOBIC INTERACTIONS DEFINITIONS
hydrophobic_unique=hydrophobic.drop_duplicates(['Residue'])
hydrophobic_unique = hydrophobic_unique.reset_index(drop=True)
hydrophobic_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<hydrophobic_unique["Residue"].size:
    freq = np.sum((hydrophobic["Residue"]==hydrophobic_unique["Residue"][x]))/(hydrophobic["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"hydrophobic",'ResName':hydrophobic_unique["ResName"][x],'Residue':hydrophobic_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        hydrophobic_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("Hydrophobic interactions by Residue number")
hydrophobic_df=pd.DataFrame(hydrophobic_db)
hydrophobic_df=hydrophobic_df.loc[~(hydrophobic_df==0).all(axis=1)]
print(pd.DataFrame(hydrophobic_df))

#IONIC INTERACTIONS
ionic_unique=ionic.drop_duplicates(['Residue'])
ionic_unique = ionic_unique.reset_index(drop=True)
ionic_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<ionic_unique["Residue"].size:
    freq = np.sum((ionic["Residue"]==ionic_unique["Residue"][x]))/(ionic["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"ionic",'ResName':ionic_unique["ResName"][x],'Residue':ionic_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        ionic_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("Ionic interactions by Residue number")
ionic_df=pd.DataFrame(ionic_db)
ionic_df=ionic_df.loc[~(ionic_df==0).all(axis=1)]
print(pd.DataFrame(ionic_df))

#PI-PI INTERACTIONS
pipi_unique=pipi.drop_duplicates(['Residue'])
pipi_unique = pipi_unique.reset_index(drop=True)
pipi_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<pipi_unique["Residue"].size:
    freq = np.sum((pipi["Residue"]==pipi_unique["Residue"][x]))/(pipi["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"pi-pi",'ResName':pipi_unique["ResName"][x],'Residue':pipi_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        pipi_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("pi-pi interactions by Residue number")
pipi_df=pd.DataFrame(pipi_db)
pipi_df=pipi_df.loc[~(pipi_df==0).all(axis=1)]
print(pd.DataFrame(pipi_df))

#WATER INTERACTIONS
water_unique=water.drop_duplicates(['Residue'])
water_unique = water_unique.reset_index(drop=True)
water_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<water_unique["Residue"].size:
    freq = np.sum((water["Residue"]==water_unique["Residue"][x]))/(water["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"water",'ResName':water_unique["ResName"][x],'Residue':water_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        water_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("water-mediated interactions by Residue number")
water_df=pd.DataFrame(water_db)
water_df=water_df.loc[~(water_df==0).all(axis=1)]
print(pd.DataFrame(water_df))
# Out:
# hydrogen bond by Residue and AtomName number
#      Type ResName  Residue AtomName  Frequency
# 1   hbond     ILE      203        O  49.686520
# 2   hbond     HIS      162      NE2  34.639498
# 3   hbond     GLN      164     HE22  15.086207
# 4   hbond     GLY      182        O  49.686520
# 5   hbond     GLU       73        O  49.725705
# 6   hbond     GLN      164     HE21  15.086207
# 7   hbond     GLY      281        O  49.686520
# 8   hbond     VAL      144        O  49.686520
# 9   hbond     TYR      278        O  49.686520
# 10  hbond     GLU      252        O  49.686520
# 11  hbond     GLN      164        H  15.164577
# 12  hbond     ILE      176        O  49.686520
# 13  hbond     HIS       56      NE2  34.639498
# 14  hbond     TYR      243        O  49.686520
# 15  hbond     ARG      159        O  49.686520
# Hydrophobic interactions by Residue number
#           Type ResName  Residue  Frequency
# 1  hydrophobic     TYR      114  86.666667
# 2  hydrophobic     ILE      203  20.000000
# Ionic interactions by Residue number
# Empty DataFrame
# Columns: [Type, ResName, Residue, Frequency]
# Index: []
# pi-pi interactions by Residue number
# Empty DataFrame
# Columns: [Type, ResName, Residue, Frequency]
# Index: []
# water-mediated interactions by Residue number
#     Type ResName  Residue  Frequency
# 1  water     GLN      164  63.736264
# 2  water     LEU      165  15.750916

# %%
#In case you want to have different styles : https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
frames = pd.concat([hbond_df,water_df,hydrophobic_df,ionic_df,pipi_df])
#frames.to_csv('interactions.tsv', sep = '\t')
print(frames)
frames.to_csv('interactions_{}.tsv'.format(name), sep='\t')
# Out:
#            Type ResName  Residue AtomName  Frequency
# 1         hbond     ILE      203        O  49.686520
# 2         hbond     HIS      162      NE2  34.639498
# 3         hbond     GLN      164     HE22  15.086207
# 4         hbond     GLY      182        O  49.686520
# 5         hbond     GLU       73        O  49.725705
# 6         hbond     GLN      164     HE21  15.086207
# 7         hbond     GLY      281        O  49.686520
# 8         hbond     VAL      144        O  49.686520
# 9         hbond     TYR      278        O  49.686520
# 10        hbond     GLU      252        O  49.686520
# 11        hbond     GLN      164        H  15.164577
# 12        hbond     ILE      176        O  49.686520
# 13        hbond     HIS       56      NE2  34.639498
# 14        hbond     TYR      243        O  49.686520
# 15        hbond     ARG      159        O  49.686520
# 1         water     GLN      164      NaN  63.736264
# 2         water     LEU      165      NaN  15.750916
# 1   hydrophobic     TYR      114      NaN  86.666667
# 2   hydrophobic     ILE      203      NaN  20.000000

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
import scipy.stats as stats
import glob

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning) #this was relevant for the String-boolean Int-boolean comparison in the Residue vs Atom double filtering below (god I miss SQL...)

# %%
# My poor less fancy importing scheme for multiple files =P
wrkdir = 'C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Results' #You have to define where the folders and subfolder will be
os.chdir(wrkdir)
name="F6P_188" #change here the name of the system, so it can pick all the files automatically

#Those features are stratified with the number of residue only
hydrophobic=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\F6P_188\\PL-Contacts_Hydrophobic.dat'.format(wrkdir, name), sep='\s+')
ionic=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\F6P_188\\PL-Contacts_Ionic.dat'.format(wrkdir, name), sep='\s+')

#Those features need the number of residue and atom for proper separation
pipi=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\F6P_188\\PL-Contacts_Pi-Pi.dat'.format(wrkdir, name), sep='\s+')
hbond=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\F6P_188\\PL-Contacts_HBond.dat'.format(wrkdir, name), sep='\s+')
water=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\F6P_188\\PL-Contacts_WaterBridge.dat'.format(wrkdir, name), sep='\s+')

# %%
#HYDROGEN BOND INTERACTIONS
hbond_unique=hbond.drop_duplicates(['Residue','AtomName'])
hbond_unique = hbond_unique.reset_index(drop=True)
hbond_db = [{'Type':0,'ResName':0,'Residue':0, 'AtomName':0,'Frequency':0}] #I setup an interaction Type variable for later help with the plotting
x=0
while x<hbond_unique["Residue"].size:
    
    freq = np.sum((hbond["Residue"]==hbond_unique["Residue"][x])|(hbond["AtomName"]==hbond_unique["AtomName"][x]))/(hbond["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"hbond",'ResName':hbond_unique["ResName"][x],'Residue':hbond_unique["Residue"][x],'AtomName':hbond_unique["AtomName"][x], 'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        hbond_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
    
print("hydrogen bond by Residue and AtomName number")
hbond_df=pd.DataFrame(hbond_db)
hbond_df=hbond_df.loc[~(hbond_df==0).all(axis=1)]
print(pd.DataFrame(hbond_df))

#HYDROPHOBIC INTERACTIONS DEFINITIONS
hydrophobic_unique=hydrophobic.drop_duplicates(['Residue'])
hydrophobic_unique = hydrophobic_unique.reset_index(drop=True)
hydrophobic_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<hydrophobic_unique["Residue"].size:
    freq = np.sum((hydrophobic["Residue"]==hydrophobic_unique["Residue"][x]))/(hydrophobic["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"hydrophobic",'ResName':hydrophobic_unique["ResName"][x],'Residue':hydrophobic_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        hydrophobic_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("Hydrophobic interactions by Residue number")
hydrophobic_df=pd.DataFrame(hydrophobic_db)
hydrophobic_df=hydrophobic_df.loc[~(hydrophobic_df==0).all(axis=1)]
print(pd.DataFrame(hydrophobic_df))

#IONIC INTERACTIONS
ionic_unique=ionic.drop_duplicates(['Residue'])
ionic_unique = ionic_unique.reset_index(drop=True)
ionic_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<ionic_unique["Residue"].size:
    freq = np.sum((ionic["Residue"]==ionic_unique["Residue"][x]))/(ionic["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"ionic",'ResName':ionic_unique["ResName"][x],'Residue':ionic_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        ionic_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("Ionic interactions by Residue number")
ionic_df=pd.DataFrame(ionic_db)
ionic_df=ionic_df.loc[~(ionic_df==0).all(axis=1)]
print(pd.DataFrame(ionic_df))

#PI-PI INTERACTIONS
pipi_unique=pipi.drop_duplicates(['Residue'])
pipi_unique = pipi_unique.reset_index(drop=True)
pipi_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<pipi_unique["Residue"].size:
    freq = np.sum((pipi["Residue"]==pipi_unique["Residue"][x]))/(pipi["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"pi-pi",'ResName':pipi_unique["ResName"][x],'Residue':pipi_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        pipi_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("pi-pi interactions by Residue number")
pipi_df=pd.DataFrame(pipi_db)
pipi_df=pipi_df.loc[~(pipi_df==0).all(axis=1)]
print(pd.DataFrame(pipi_df))

#WATER INTERACTIONS
water_unique=water.drop_duplicates(['Residue'])
water_unique = water_unique.reset_index(drop=True)
water_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<water_unique["Residue"].size:
    freq = np.sum((water["Residue"]==water_unique["Residue"][x]))/(water["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"water",'ResName':water_unique["ResName"][x],'Residue':water_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        water_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("water-mediated interactions by Residue number")
water_df=pd.DataFrame(water_db)
water_df=water_df.loc[~(water_df==0).all(axis=1)]
print(pd.DataFrame(water_df))
# Out:
# hydrogen bond by Residue and AtomName number
#      Type ResName  Residue AtomName  Frequency
# 1   hbond     ASP      181      OD1  13.414360
# 2   hbond     ASP      183      OD1  17.994598
# 3   hbond     TYR      114       HH  11.444970
# 4   hbond     ARG      159       HE  22.293495
# 5   hbond     ARG      159     HH21  22.282242
# 6   hbond     ARG      161     HH12  22.563583
# 7   hbond     ARG      161     HH22  22.563583
# 8   hbond     GLY      182        H  21.494486
# 9   hbond     GLY      205        H  21.494486
# 10  hbond     ASP      183      OD2  18.928652
# 11  hbond     ASP      181      OD2  14.888589
# 12  hbond     ASP      183        H  36.596894
# 13  hbond     ASP      244      OD2  12.131443
# 14  hbond     ASP       79      OD2  12.120189
# 15  hbond     ARG      305       HE  10.859779
# 16  hbond     ASP      129      OD2  12.120189
# 17  hbond     ARG      217       HE  10.871033
# 18  hbond     ARG      217     HH21  11.456223
# 19  hbond     GLU      258        H  21.494486
# 20  hbond     ASP       32      OD2  12.131443
# 21  hbond     ASP      244        H  21.505739
# Hydrophobic interactions by Residue number
#           Type ResName  Residue   Frequency
# 1  hydrophobic     LEU      157  100.512821
# Ionic interactions by Residue number
# Empty DataFrame
# Columns: [Type, ResName, Residue, Frequency]
# Index: []
# pi-pi interactions by Residue number
# Empty DataFrame
# Columns: [Type, ResName, Residue, Frequency]
# Index: []
# water-mediated interactions by Residue number
#     Type ResName  Residue  Frequency
# 1  water     ASP      181  45.953757
# 2  water     GLY      182  13.150289
# 3  water     ASP       82  13.150289
# 4  water     ASP      183  10.260116

# %%
#In case you want to have different styles : https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
frames = pd.concat([hbond_df,water_df,hydrophobic_df,ionic_df,pipi_df])
#frames.to_csv('interactions.tsv', sep = '\t')
print(frames)
frames.to_csv('interactions_{}.tsv'.format(name), sep='\t')
# Out:
#            Type ResName  Residue AtomName   Frequency
# 1         hbond     ASP      181      OD1   13.414360
# 2         hbond     ASP      183      OD1   17.994598
# 3         hbond     TYR      114       HH   11.444970
# 4         hbond     ARG      159       HE   22.293495
# 5         hbond     ARG      159     HH21   22.282242
# 6         hbond     ARG      161     HH12   22.563583
# 7         hbond     ARG      161     HH22   22.563583
# 8         hbond     GLY      182        H   21.494486
# 9         hbond     GLY      205        H   21.494486
# 10        hbond     ASP      183      OD2   18.928652
# 11        hbond     ASP      181      OD2   14.888589
# 12        hbond     ASP      183        H   36.596894
# 13        hbond     ASP      244      OD2   12.131443
# 14        hbond     ASP       79      OD2   12.120189
# 15        hbond     ARG      305       HE   10.859779
# 16        hbond     ASP      129      OD2   12.120189
# 17        hbond     ARG      217       HE   10.871033
# 18        hbond     ARG      217     HH21   11.456223
# 19        hbond     GLU      258        H   21.494486
# 20        hbond     ASP       32      OD2   12.131443
# 21        hbond     ASP      244        H   21.505739
# 1         water     ASP      181      NaN   45.953757
# 2         water     GLY      182      NaN   13.150289
# 3         water     ASP       82      NaN   13.150289
# 4         water     ASP      183      NaN   10.260116
# 1   hydrophobic     LEU      157      NaN  100.512821

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
import scipy.stats as stats
import glob

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning) #this was relevant for the String-boolean Int-boolean comparison in the Residue vs Atom double filtering below (god I miss SQL...)

# %%
# My poor less fancy importing scheme for multiple files =P
wrkdir = 'C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Results' #You have to define where the folders and subfolder will be
os.chdir(wrkdir)
name="F6P_189" #change here the name of the system, so it can pick all the files automatically

#Those features are stratified with the number of residue only
hydrophobic=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\F6P_189\\PL-Contacts_Hydrophobic.dat'.format(wrkdir, name), sep='\s+')
ionic=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\F6P_189\\PL-Contacts_Ionic.dat'.format(wrkdir, name), sep='\s+')

#Those features need the number of residue and atom for proper separation
pipi=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\F6P_189\\PL-Contacts_Pi-Pi.dat'.format(wrkdir, name), sep='\s+')
hbond=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\F6P_189\\PL-Contacts_HBond.dat'.format(wrkdir, name), sep='\s+')
water=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\F6P_189\\PL-Contacts_WaterBridge.dat'.format(wrkdir, name), sep='\s+')

# %%
#HYDROGEN BOND INTERACTIONS
hbond_unique=hbond.drop_duplicates(['Residue','AtomName'])
hbond_unique = hbond_unique.reset_index(drop=True)
hbond_db = [{'Type':0,'ResName':0,'Residue':0, 'AtomName':0,'Frequency':0}] #I setup an interaction Type variable for later help with the plotting
x=0
while x<hbond_unique["Residue"].size:
    
    freq = np.sum((hbond["Residue"]==hbond_unique["Residue"][x])|(hbond["AtomName"]==hbond_unique["AtomName"][x]))/(hbond["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"hbond",'ResName':hbond_unique["ResName"][x],'Residue':hbond_unique["Residue"][x],'AtomName':hbond_unique["AtomName"][x], 'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        hbond_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
    
print("hydrogen bond by Residue and AtomName number")
hbond_df=pd.DataFrame(hbond_db)
hbond_df=hbond_df.loc[~(hbond_df==0).all(axis=1)]
print(pd.DataFrame(hbond_df))

#HYDROPHOBIC INTERACTIONS DEFINITIONS
hydrophobic_unique=hydrophobic.drop_duplicates(['Residue'])
hydrophobic_unique = hydrophobic_unique.reset_index(drop=True)
hydrophobic_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<hydrophobic_unique["Residue"].size:
    freq = np.sum((hydrophobic["Residue"]==hydrophobic_unique["Residue"][x]))/(hydrophobic["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"hydrophobic",'ResName':hydrophobic_unique["ResName"][x],'Residue':hydrophobic_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        hydrophobic_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("Hydrophobic interactions by Residue number")
hydrophobic_df=pd.DataFrame(hydrophobic_db)
hydrophobic_df=hydrophobic_df.loc[~(hydrophobic_df==0).all(axis=1)]
print(pd.DataFrame(hydrophobic_df))

#IONIC INTERACTIONS
ionic_unique=ionic.drop_duplicates(['Residue'])
ionic_unique = ionic_unique.reset_index(drop=True)
ionic_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<ionic_unique["Residue"].size:
    freq = np.sum((ionic["Residue"]==ionic_unique["Residue"][x]))/(ionic["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"ionic",'ResName':ionic_unique["ResName"][x],'Residue':ionic_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        ionic_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("Ionic interactions by Residue number")
ionic_df=pd.DataFrame(ionic_db)
ionic_df=ionic_df.loc[~(ionic_df==0).all(axis=1)]
print(pd.DataFrame(ionic_df))

#PI-PI INTERACTIONS
pipi_unique=pipi.drop_duplicates(['Residue'])
pipi_unique = pipi_unique.reset_index(drop=True)
pipi_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<pipi_unique["Residue"].size:
    freq = np.sum((pipi["Residue"]==pipi_unique["Residue"][x]))/(pipi["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"pi-pi",'ResName':pipi_unique["ResName"][x],'Residue':pipi_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        pipi_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("pi-pi interactions by Residue number")
pipi_df=pd.DataFrame(pipi_db)
pipi_df=pipi_df.loc[~(pipi_df==0).all(axis=1)]
print(pd.DataFrame(pipi_df))

#WATER INTERACTIONS
water_unique=water.drop_duplicates(['Residue'])
water_unique = water_unique.reset_index(drop=True)
water_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<water_unique["Residue"].size:
    freq = np.sum((water["Residue"]==water_unique["Residue"][x]))/(water["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"water",'ResName':water_unique["ResName"][x],'Residue':water_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        water_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("water-mediated interactions by Residue number")
water_df=pd.DataFrame(water_db)
water_df=water_df.loc[~(water_df==0).all(axis=1)]
print(pd.DataFrame(water_df))
# Out:
# hydrogen bond by Residue and AtomName number
#      Type ResName  Residue AtomName  Frequency
# 1   hbond     ASP      181      OD1  15.884908
# 2   hbond     ASP      183      OD1  19.315961
# 3   hbond     TYR      114       HH  10.825190
# 4   hbond     ARG      159     HH21  20.955483
# 5   hbond     ARG      161     HH12  21.813246
# 6   hbond     ARG      161     HH22  21.824104
# 7   hbond     GLY      182        H  21.986971
# 8   hbond     GLY      205        H  21.498371
# 9   hbond     ARG      159       HE  20.966341
# 10  hbond     ASP      183      OD2  21.205212
# 11  hbond     ASP      181      OD2  15.114007
# 12  hbond     ARG      139       HE  10.228013
# 13  hbond     ARG      103     HH12  10.912052
# 14  hbond     ARG      235     HH12  10.933768
# 15  hbond     ASP       70      OD1  11.335505
# 16  hbond     ARG      298       HE  10.228013
# 17  hbond     ARG      159     HH22  31.856678
# 18  hbond     THR      296        H  21.509229
# 19  hbond     ASP      146      OD1  11.324647
# 20  hbond     ASP      183        H  38.165038
# 21  hbond     ASP      158      OD2  12.486428
# 22  hbond     SER      294        H  21.520087
# 23  hbond     GLY      295        H  21.498371
# 24  hbond     THR      153        H  21.498371
# 25  hbond     ASP       70      OD2  12.508143
# 26  hbond     ASP      123      OD1  11.324647
# 27  hbond     ARG      305     HH12  10.912052
# 28  hbond     GLY      182        O  11.932682
# 29  hbond     ARG      291     HH22  10.944625
# 30  hbond     ASP      253      OD1  11.324647
# 31  hbond     ARG      235     HH21  10.738328
# 32  hbond     ASP      198      OD1  11.324647
# Hydrophobic interactions by Residue number
#           Type ResName  Residue   Frequency
# 1  hydrophobic     LEU      157  100.662252
# Ionic interactions by Residue number
# Empty DataFrame
# Columns: [Type, ResName, Residue, Frequency]
# Index: []
# pi-pi interactions by Residue number
# Empty DataFrame
# Columns: [Type, ResName, Residue, Frequency]
# Index: []
# water-mediated interactions by Residue number
#     Type ResName  Residue  Frequency
# 1  water     ASP      181  41.897233
# 2  water     ASP       82  16.521739

# %%
#In case you want to have different styles : https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
frames = pd.concat([hbond_df,water_df,hydrophobic_df,ionic_df,pipi_df])
#frames.to_csv('interactions.tsv', sep = '\t')
print(frames)
frames.to_csv('interactions_{}.tsv'.format(name), sep='\t')
# Out:
#            Type ResName  Residue AtomName   Frequency
# 1         hbond     ASP      181      OD1   15.884908
# 2         hbond     ASP      183      OD1   19.315961
# 3         hbond     TYR      114       HH   10.825190
# 4         hbond     ARG      159     HH21   20.955483
# 5         hbond     ARG      161     HH12   21.813246
# 6         hbond     ARG      161     HH22   21.824104
# 7         hbond     GLY      182        H   21.986971
# 8         hbond     GLY      205        H   21.498371
# 9         hbond     ARG      159       HE   20.966341
# 10        hbond     ASP      183      OD2   21.205212
# 11        hbond     ASP      181      OD2   15.114007
# 12        hbond     ARG      139       HE   10.228013
# 13        hbond     ARG      103     HH12   10.912052
# 14        hbond     ARG      235     HH12   10.933768
# 15        hbond     ASP       70      OD1   11.335505
# 16        hbond     ARG      298       HE   10.228013
# 17        hbond     ARG      159     HH22   31.856678
# 18        hbond     THR      296        H   21.509229
# 19        hbond     ASP      146      OD1   11.324647
# 20        hbond     ASP      183        H   38.165038
# 21        hbond     ASP      158      OD2   12.486428
# 22        hbond     SER      294        H   21.520087
# 23        hbond     GLY      295        H   21.498371
# 24        hbond     THR      153        H   21.498371
# 25        hbond     ASP       70      OD2   12.508143
# 26        hbond     ASP      123      OD1   11.324647
# 27        hbond     ARG      305     HH12   10.912052
# 28        hbond     GLY      182        O   11.932682
# 29        hbond     ARG      291     HH22   10.944625
# 30        hbond     ASP      253      OD1   11.324647
# 31        hbond     ARG      235     HH21   10.738328
# 32        hbond     ASP      198      OD1   11.324647
# 1         water     ASP      181      NaN   41.897233
# 2         water     ASP       82      NaN   16.521739
# 1   hydrophobic     LEU      157      NaN  100.662252

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
import scipy.stats as stats
import glob

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning) #this was relevant for the String-boolean Int-boolean comparison in the Residue vs Atom double filtering below (god I miss SQL...)

# %%
# My poor less fancy importing scheme for multiple files =P
wrkdir = 'C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Results' #You have to define where the folders and subfolder will be
os.chdir(wrkdir)
name="Gln164_188" #change here the name of the system, so it can pick all the files automatically

#Those features are stratified with the number of residue only
hydrophobic=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Gln164_188\\PL-Contacts_Hydrophobic.dat'.format(wrkdir, name), sep='\s+')
ionic=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Gln164_188\\PL-Contacts_Ionic.dat'.format(wrkdir, name), sep='\s+')

#Those features need the number of residue and atom for proper separation
pipi=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Gln164_188\\PL-Contacts_Pi-Pi.dat'.format(wrkdir, name), sep='\s+')
hbond=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Gln164_188\\PL-Contacts_HBond.dat'.format(wrkdir, name), sep='\s+')
water=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Gln164_188\\PL-Contacts_WaterBridge.dat'.format(wrkdir, name), sep='\s+')

# %%
#HYDROGEN BOND INTERACTIONS
hbond_unique=hbond.drop_duplicates(['Residue','AtomName'])
hbond_unique = hbond_unique.reset_index(drop=True)
hbond_db = [{'Type':0,'ResName':0,'Residue':0, 'AtomName':0,'Frequency':0}] #I setup an interaction Type variable for later help with the plotting
x=0
while x<hbond_unique["Residue"].size:
    
    freq = np.sum((hbond["Residue"]==hbond_unique["Residue"][x])|(hbond["AtomName"]==hbond_unique["AtomName"][x]))/(hbond["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"hbond",'ResName':hbond_unique["ResName"][x],'Residue':hbond_unique["Residue"][x],'AtomName':hbond_unique["AtomName"][x], 'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        hbond_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
    
print("hydrogen bond by Residue and AtomName number")
hbond_df=pd.DataFrame(hbond_db)
hbond_df=hbond_df.loc[~(hbond_df==0).all(axis=1)]
print(pd.DataFrame(hbond_df))

#HYDROPHOBIC INTERACTIONS DEFINITIONS
hydrophobic_unique=hydrophobic.drop_duplicates(['Residue'])
hydrophobic_unique = hydrophobic_unique.reset_index(drop=True)
hydrophobic_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<hydrophobic_unique["Residue"].size:
    freq = np.sum((hydrophobic["Residue"]==hydrophobic_unique["Residue"][x]))/(hydrophobic["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"hydrophobic",'ResName':hydrophobic_unique["ResName"][x],'Residue':hydrophobic_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        hydrophobic_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("Hydrophobic interactions by Residue number")
hydrophobic_df=pd.DataFrame(hydrophobic_db)
hydrophobic_df=hydrophobic_df.loc[~(hydrophobic_df==0).all(axis=1)]
print(pd.DataFrame(hydrophobic_df))

#IONIC INTERACTIONS
ionic_unique=ionic.drop_duplicates(['Residue'])
ionic_unique = ionic_unique.reset_index(drop=True)
ionic_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<ionic_unique["Residue"].size:
    freq = np.sum((ionic["Residue"]==ionic_unique["Residue"][x]))/(ionic["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"ionic",'ResName':ionic_unique["ResName"][x],'Residue':ionic_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        ionic_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("Ionic interactions by Residue number")
ionic_df=pd.DataFrame(ionic_db)
ionic_df=ionic_df.loc[~(ionic_df==0).all(axis=1)]
print(pd.DataFrame(ionic_df))

#PI-PI INTERACTIONS
pipi_unique=pipi.drop_duplicates(['Residue'])
pipi_unique = pipi_unique.reset_index(drop=True)
pipi_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<pipi_unique["Residue"].size:
    freq = np.sum((pipi["Residue"]==pipi_unique["Residue"][x]))/(pipi["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"pi-pi",'ResName':pipi_unique["ResName"][x],'Residue':pipi_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        pipi_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("pi-pi interactions by Residue number")
pipi_df=pd.DataFrame(pipi_db)
pipi_df=pipi_df.loc[~(pipi_df==0).all(axis=1)]
print(pd.DataFrame(pipi_df))

#WATER INTERACTIONS
water_unique=water.drop_duplicates(['Residue'])
water_unique = water_unique.reset_index(drop=True)
water_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<water_unique["Residue"].size:
    freq = np.sum((water["Residue"]==water_unique["Residue"][x]))/(water["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"water",'ResName':water_unique["ResName"][x],'Residue':water_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        water_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("water-mediated interactions by Residue number")
water_df=pd.DataFrame(water_db)
water_df=water_df.loc[~(water_df==0).all(axis=1)]
print(pd.DataFrame(water_df))
# Out:
# hydrogen bond by Residue and AtomName number
#      Type ResName  Residue AtomName  Frequency
# 1   hbond     ASP      168      OD1  63.295378
# 2   hbond     HIS      167        H  65.505693
# 3   hbond     ASP      168        H  70.663094
# 4   hbond     ASP      168      OD2  63.295378
# 5   hbond     SER      195        O  25.385131
# 6   hbond     LEU      272        O  25.385131
# 7   hbond     ARG      103        O  25.385131
# 8   hbond     ARG      161        O  25.385131
# 9   hbond     GLY       90        O  25.385131
# 10  hbond     LEU      165        H  62.290690
# 11  hbond     SER      294        O  25.385131
# 12  hbond     ASP      232        O  25.385131
# 13  hbond     LEU      306        O  25.385131
# 14  hbond     ASN       62        O  25.385131
# 15  hbond     LYS       54        H  62.290690
# 16  hbond     ALA      241        O  25.385131
# 17  hbond     ARG      305        H  62.290690
# 18  hbond     HIS      126        O  25.385131
# 19  hbond     PRO      229        O  25.385131
# Hydrophobic interactions by Residue number
#           Type ResName  Residue  Frequency
# 1  hydrophobic     LEU      165      110.0
# Ionic interactions by Residue number
# Empty DataFrame
# Columns: [Type, ResName, Residue, Frequency]
# Index: []
# pi-pi interactions by Residue number
# Empty DataFrame
# Columns: [Type, ResName, Residue, Frequency]
# Index: []
# water-mediated interactions by Residue number
#     Type ResName  Residue  Frequency
# 1  water     ASP      168  51.965066
# 2  water     ARG      161  23.799127

# %%
#In case you want to have different styles : https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
frames = pd.concat([hbond_df,water_df,hydrophobic_df,ionic_df,pipi_df])
#frames.to_csv('interactions.tsv', sep = '\t')
print(frames)
frames.to_csv('interactions_{}.tsv'.format(name), sep='\t')
# Out:
#            Type ResName  Residue AtomName   Frequency
# 1         hbond     ASP      168      OD1   63.295378
# 2         hbond     HIS      167        H   65.505693
# 3         hbond     ASP      168        H   70.663094
# 4         hbond     ASP      168      OD2   63.295378
# 5         hbond     SER      195        O   25.385131
# 6         hbond     LEU      272        O   25.385131
# 7         hbond     ARG      103        O   25.385131
# 8         hbond     ARG      161        O   25.385131
# 9         hbond     GLY       90        O   25.385131
# 10        hbond     LEU      165        H   62.290690
# 11        hbond     SER      294        O   25.385131
# 12        hbond     ASP      232        O   25.385131
# 13        hbond     LEU      306        O   25.385131
# 14        hbond     ASN       62        O   25.385131
# 15        hbond     LYS       54        H   62.290690
# 16        hbond     ALA      241        O   25.385131
# 17        hbond     ARG      305        H   62.290690
# 18        hbond     HIS      126        O   25.385131
# 19        hbond     PRO      229        O   25.385131
# 1         water     ASP      168      NaN   51.965066
# 2         water     ARG      161      NaN   23.799127
# 1   hydrophobic     LEU      165      NaN  110.000000

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
import scipy.stats as stats
import glob

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning) #this was relevant for the String-boolean Int-boolean comparison in the Residue vs Atom double filtering below (god I miss SQL...)

# %%
# My poor less fancy importing scheme for multiple files =P
wrkdir = 'C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Results' #You have to define where the folders and subfolder will be
os.chdir(wrkdir)
name="Gln164_189" #change here the name of the system, so it can pick all the files automatically

#Those features are stratified with the number of residue only
hydrophobic=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Gln164_189\\PL-Contacts_Hydrophobic.dat'.format(wrkdir, name), sep='\s+')
ionic=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Gln164_189\\PL-Contacts_Ionic.dat'.format(wrkdir, name), sep='\s+')

#Those features need the number of residue and atom for proper separation
pipi=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Gln164_189\\PL-Contacts_Pi-Pi.dat'.format(wrkdir, name), sep='\s+')
hbond=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Gln164_189\\PL-Contacts_HBond.dat'.format(wrkdir, name), sep='\s+')
water=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Gln164_189\\PL-Contacts_WaterBridge.dat'.format(wrkdir, name), sep='\s+')

# %%
#HYDROGEN BOND INTERACTIONS
hbond_unique=hbond.drop_duplicates(['Residue','AtomName'])
hbond_unique = hbond_unique.reset_index(drop=True)
hbond_db = [{'Type':0,'ResName':0,'Residue':0, 'AtomName':0,'Frequency':0}] #I setup an interaction Type variable for later help with the plotting
x=0
while x<hbond_unique["Residue"].size:
    
    freq = np.sum((hbond["Residue"]==hbond_unique["Residue"][x])|(hbond["AtomName"]==hbond_unique["AtomName"][x]))/(hbond["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"hbond",'ResName':hbond_unique["ResName"][x],'Residue':hbond_unique["Residue"][x],'AtomName':hbond_unique["AtomName"][x], 'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        hbond_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
    
print("hydrogen bond by Residue and AtomName number")
hbond_df=pd.DataFrame(hbond_db)
hbond_df=hbond_df.loc[~(hbond_df==0).all(axis=1)]
print(pd.DataFrame(hbond_df))

#HYDROPHOBIC INTERACTIONS DEFINITIONS
hydrophobic_unique=hydrophobic.drop_duplicates(['Residue'])
hydrophobic_unique = hydrophobic_unique.reset_index(drop=True)
hydrophobic_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<hydrophobic_unique["Residue"].size:
    freq = np.sum((hydrophobic["Residue"]==hydrophobic_unique["Residue"][x]))/(hydrophobic["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"hydrophobic",'ResName':hydrophobic_unique["ResName"][x],'Residue':hydrophobic_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        hydrophobic_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("Hydrophobic interactions by Residue number")
hydrophobic_df=pd.DataFrame(hydrophobic_db)
hydrophobic_df=hydrophobic_df.loc[~(hydrophobic_df==0).all(axis=1)]
print(pd.DataFrame(hydrophobic_df))

#IONIC INTERACTIONS
ionic_unique=ionic.drop_duplicates(['Residue'])
ionic_unique = ionic_unique.reset_index(drop=True)
ionic_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<ionic_unique["Residue"].size:
    freq = np.sum((ionic["Residue"]==ionic_unique["Residue"][x]))/(ionic["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"ionic",'ResName':ionic_unique["ResName"][x],'Residue':ionic_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        ionic_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("Ionic interactions by Residue number")
ionic_df=pd.DataFrame(ionic_db)
ionic_df=ionic_df.loc[~(ionic_df==0).all(axis=1)]
print(pd.DataFrame(ionic_df))

#PI-PI INTERACTIONS
pipi_unique=pipi.drop_duplicates(['Residue'])
pipi_unique = pipi_unique.reset_index(drop=True)
pipi_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<pipi_unique["Residue"].size:
    freq = np.sum((pipi["Residue"]==pipi_unique["Residue"][x]))/(pipi["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"pi-pi",'ResName':pipi_unique["ResName"][x],'Residue':pipi_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        pipi_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("pi-pi interactions by Residue number")
pipi_df=pd.DataFrame(pipi_db)
pipi_df=pipi_df.loc[~(pipi_df==0).all(axis=1)]
print(pd.DataFrame(pipi_df))

#WATER INTERACTIONS
water_unique=water.drop_duplicates(['Residue'])
water_unique = water_unique.reset_index(drop=True)
water_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<water_unique["Residue"].size:
    freq = np.sum((water["Residue"]==water_unique["Residue"][x]))/(water["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"water",'ResName':water_unique["ResName"][x],'Residue':water_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        water_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("water-mediated interactions by Residue number")
water_df=pd.DataFrame(water_db)
water_df=water_df.loc[~(water_df==0).all(axis=1)]
print(pd.DataFrame(water_df))
# Out:
# hydrogen bond by Residue and AtomName number
#      Type ResName  Residue AtomName  Frequency
# 1   hbond     ASP      168      OD1  61.040694
# 2   hbond     ASP      168        H  69.646431
# 3   hbond     ARG      161        O  26.684456
# 4   hbond     LEU      165        H  63.175450
# 5   hbond     ASP      269        H  63.175450
# 6   hbond     LEU      239        O  26.684456
# 7   hbond     ASP      168      OD2  60.907272
# 8   hbond     SER      307        H  63.175450
# 9   hbond     TB4      801        O  27.018012
# 10  hbond     ALA      163        H  63.175450
# 11  hbond     HIS      167        H  65.510340
# 12  hbond     GLY       28        O  26.684456
# 13  hbond     VAL      248        O  26.684456
# 14  hbond     GLY      295        O  26.684456
# 15  hbond     SER      294        O  26.751167
# 16  hbond     ASP      271        O  26.684456
# 17  hbond     TYR      278        O  26.684456
# 18  hbond     VAL      260        O  26.684456
# 19  hbond     PRO       58        O  26.684456
# 20  hbond     ARG      291        O  26.751167
# 21  hbond     SER      294        H  63.242161
# 22  hbond     ARG      217        O  26.684456
# 23  hbond     SER      292        H  63.242161
# Hydrophobic interactions by Residue number
#           Type ResName  Residue  Frequency
# 1  hydrophobic     LEU      165      112.5
# Ionic interactions by Residue number
# Empty DataFrame
# Columns: [Type, ResName, Residue, Frequency]
# Index: []
# pi-pi interactions by Residue number
# Empty DataFrame
# Columns: [Type, ResName, Residue, Frequency]
# Index: []
# water-mediated interactions by Residue number
#     Type ResName  Residue  Frequency
# 1  water     ARG      161  24.982505
# 2  water     ASP      168  50.944717

# %%
#In case you want to have different styles : https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
frames = pd.concat([hbond_df,water_df,hydrophobic_df,ionic_df,pipi_df])
#frames.to_csv('interactions.tsv', sep = '\t')
print(frames)
frames.to_csv('interactions_{}.tsv'.format(name), sep='\t')
# Out:
#            Type ResName  Residue AtomName   Frequency
# 1         hbond     ASP      168      OD1   61.040694
# 2         hbond     ASP      168        H   69.646431
# 3         hbond     ARG      161        O   26.684456
# 4         hbond     LEU      165        H   63.175450
# 5         hbond     ASP      269        H   63.175450
# 6         hbond     LEU      239        O   26.684456
# 7         hbond     ASP      168      OD2   60.907272
# 8         hbond     SER      307        H   63.175450
# 9         hbond     TB4      801        O   27.018012
# 10        hbond     ALA      163        H   63.175450
# 11        hbond     HIS      167        H   65.510340
# 12        hbond     GLY       28        O   26.684456
# 13        hbond     VAL      248        O   26.684456
# 14        hbond     GLY      295        O   26.684456
# 15        hbond     SER      294        O   26.751167
# 16        hbond     ASP      271        O   26.684456
# 17        hbond     TYR      278        O   26.684456
# 18        hbond     VAL      260        O   26.684456
# 19        hbond     PRO       58        O   26.684456
# 20        hbond     ARG      291        O   26.751167
# 21        hbond     SER      294        H   63.242161
# 22        hbond     ARG      217        O   26.684456
# 23        hbond     SER      292        H   63.242161
# 1         water     ARG      161      NaN   24.982505
# 2         water     ASP      168      NaN   50.944717
# 1   hydrophobic     LEU      165      NaN  112.500000

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
import scipy.stats as stats
import glob

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning) #this was relevant for the String-boolean Int-boolean comparison in the Residue vs Atom double filtering below (god I miss SQL...)

# %%
# My poor less fancy importing scheme for multiple files =P
wrkdir = 'C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Results' #You have to define where the folders and subfolder will be
os.chdir(wrkdir)
name="Ser84_188" #change here the name of the system, so it can pick all the files automatically

#Those features are stratified with the number of residue only
hydrophobic=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Ser84_188\\PL-Contacts_Hydrophobic.dat'.format(wrkdir, name), sep='\s+')
ionic=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Ser84_188\\PL-Contacts_Ionic.dat'.format(wrkdir, name), sep='\s+')

#Those features need the number of residue and atom for proper separation
pipi=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Ser84_188\\PL-Contacts_Pi-Pi.dat'.format(wrkdir, name), sep='\s+')
hbond=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Ser84_188\\PL-Contacts_HBond.dat'.format(wrkdir, name), sep='\s+')
water=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Ser84_188\\PL-Contacts_WaterBridge.dat'.format(wrkdir, name), sep='\s+')

# %%
#HYDROGEN BOND INTERACTIONS
hbond_unique=hbond.drop_duplicates(['Residue','AtomName'])
hbond_unique = hbond_unique.reset_index(drop=True)
hbond_db = [{'Type':0,'ResName':0,'Residue':0, 'AtomName':0,'Frequency':0}] #I setup an interaction Type variable for later help with the plotting
x=0
while x<hbond_unique["Residue"].size:
    
    freq = np.sum((hbond["Residue"]==hbond_unique["Residue"][x])|(hbond["AtomName"]==hbond_unique["AtomName"][x]))/(hbond["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"hbond",'ResName':hbond_unique["ResName"][x],'Residue':hbond_unique["Residue"][x],'AtomName':hbond_unique["AtomName"][x], 'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        hbond_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
    
print("hydrogen bond by Residue and AtomName number")
hbond_df=pd.DataFrame(hbond_db)
hbond_df=hbond_df.loc[~(hbond_df==0).all(axis=1)]
print(pd.DataFrame(hbond_df))

#HYDROPHOBIC INTERACTIONS DEFINITIONS
hydrophobic_unique=hydrophobic.drop_duplicates(['Residue'])
hydrophobic_unique = hydrophobic_unique.reset_index(drop=True)
hydrophobic_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<hydrophobic_unique["Residue"].size:
    freq = np.sum((hydrophobic["Residue"]==hydrophobic_unique["Residue"][x]))/(hydrophobic["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"hydrophobic",'ResName':hydrophobic_unique["ResName"][x],'Residue':hydrophobic_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        hydrophobic_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("Hydrophobic interactions by Residue number")
hydrophobic_df=pd.DataFrame(hydrophobic_db)
hydrophobic_df=hydrophobic_df.loc[~(hydrophobic_df==0).all(axis=1)]
print(pd.DataFrame(hydrophobic_df))

#IONIC INTERACTIONS
ionic_unique=ionic.drop_duplicates(['Residue'])
ionic_unique = ionic_unique.reset_index(drop=True)
ionic_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<ionic_unique["Residue"].size:
    freq = np.sum((ionic["Residue"]==ionic_unique["Residue"][x]))/(ionic["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"ionic",'ResName':ionic_unique["ResName"][x],'Residue':ionic_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        ionic_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("Ionic interactions by Residue number")
ionic_df=pd.DataFrame(ionic_db)
ionic_df=ionic_df.loc[~(ionic_df==0).all(axis=1)]
print(pd.DataFrame(ionic_df))

#PI-PI INTERACTIONS
pipi_unique=pipi.drop_duplicates(['Residue'])
pipi_unique = pipi_unique.reset_index(drop=True)
pipi_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<pipi_unique["Residue"].size:
    freq = np.sum((pipi["Residue"]==pipi_unique["Residue"][x]))/(pipi["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"pi-pi",'ResName':pipi_unique["ResName"][x],'Residue':pipi_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        pipi_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("pi-pi interactions by Residue number")
pipi_df=pd.DataFrame(pipi_db)
pipi_df=pipi_df.loc[~(pipi_df==0).all(axis=1)]
print(pd.DataFrame(pipi_df))

#WATER INTERACTIONS
water_unique=water.drop_duplicates(['Residue'])
water_unique = water_unique.reset_index(drop=True)
water_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<water_unique["Residue"].size:
    freq = np.sum((water["Residue"]==water_unique["Residue"][x]))/(water["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"water",'ResName':water_unique["ResName"][x],'Residue':water_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        water_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("water-mediated interactions by Residue number")
water_df=pd.DataFrame(water_db)
water_df=water_df.loc[~(water_df==0).all(axis=1)]
print(pd.DataFrame(water_df))
# Out:
# hydrogen bond by Residue and AtomName number
#     Type ResName  Residue AtomName  Frequency
# 1  hbond     SER       88        H  80.023502
# 2  hbond     SER       88       HG  74.500588
# 3  hbond     MET       87        H  58.343126
# 4  hbond     THR       85        H  58.343126
# 5  hbond     GLY      196        H  58.343126
# 6  hbond     ASP       27        H  66.451234
# 7  hbond     TYR      278        H  58.343126
# Hydrophobic interactions by Residue number
#           Type ResName  Residue  Frequency
# 1  hydrophobic     ILE       81  95.945946
# Ionic interactions by Residue number
# Empty DataFrame
# Columns: [Type, ResName, Residue, Frequency]
# Index: []
# pi-pi interactions by Residue number
# Empty DataFrame
# Columns: [Type, ResName, Residue, Frequency]
# Index: []
# water-mediated interactions by Residue number
#     Type ResName  Residue  Frequency
# 1  water     THR       85  10.286554
# 2  water     GLY       83  33.578251
# 3  water     ASP       82  10.360029
# 4  water     ASP       27  13.886848
# 5  water     ILE       81  14.401176

# %%
#In case you want to have different styles : https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
frames = pd.concat([hbond_df,water_df,hydrophobic_df,ionic_df,pipi_df])
#frames.to_csv('interactions.tsv', sep = '\t')
print(frames)
frames.to_csv('interactions_{}.tsv'.format(name), sep='\t')
# Out:
#           Type ResName  Residue AtomName  Frequency
# 1        hbond     SER       88        H  80.023502
# 2        hbond     SER       88       HG  74.500588
# 3        hbond     MET       87        H  58.343126
# 4        hbond     THR       85        H  58.343126
# 5        hbond     GLY      196        H  58.343126
# 6        hbond     ASP       27        H  66.451234
# 7        hbond     TYR      278        H  58.343126
# 1        water     THR       85      NaN  10.286554
# 2        water     GLY       83      NaN  33.578251
# 3        water     ASP       82      NaN  10.360029
# 4        water     ASP       27      NaN  13.886848
# 5        water     ILE       81      NaN  14.401176
# 1  hydrophobic     ILE       81      NaN  95.945946

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
import scipy.stats as stats
import glob

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning) #this was relevant for the String-boolean Int-boolean comparison in the Residue vs Atom double filtering below (god I miss SQL...)

# %%
# My poor less fancy importing scheme for multiple files =P
wrkdir = 'C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Results' #You have to define where the folders and subfolder will be
os.chdir(wrkdir)
name="Ser84_189" #change here the name of the system, so it can pick all the files automatically

#Those features are stratified with the number of residue only
hydrophobic=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Ser84_189\\PL-Contacts_Hydrophobic.dat'.format(wrkdir, name), sep='\s+')
ionic=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Ser84_189\\PL-Contacts_Ionic.dat'.format(wrkdir, name), sep='\s+')

#Those features need the number of residue and atom for proper separation
pipi=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Ser84_189\\PL-Contacts_Pi-Pi.dat'.format(wrkdir, name), sep='\s+')
hbond=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Ser84_189\\PL-Contacts_HBond.dat'.format(wrkdir, name), sep='\s+')
water=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Ser84_189\\PL-Contacts_WaterBridge.dat'.format(wrkdir, name), sep='\s+')

# %%
#HYDROGEN BOND INTERACTIONS
hbond_unique=hbond.drop_duplicates(['Residue','AtomName'])
hbond_unique = hbond_unique.reset_index(drop=True)
hbond_db = [{'Type':0,'ResName':0,'Residue':0, 'AtomName':0,'Frequency':0}] #I setup an interaction Type variable for later help with the plotting
x=0
while x<hbond_unique["Residue"].size:
    
    freq = np.sum((hbond["Residue"]==hbond_unique["Residue"][x])|(hbond["AtomName"]==hbond_unique["AtomName"][x]))/(hbond["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"hbond",'ResName':hbond_unique["ResName"][x],'Residue':hbond_unique["Residue"][x],'AtomName':hbond_unique["AtomName"][x], 'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        hbond_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
    
print("hydrogen bond by Residue and AtomName number")
hbond_df=pd.DataFrame(hbond_db)
hbond_df=hbond_df.loc[~(hbond_df==0).all(axis=1)]
print(pd.DataFrame(hbond_df))

#HYDROPHOBIC INTERACTIONS DEFINITIONS
hydrophobic_unique=hydrophobic.drop_duplicates(['Residue'])
hydrophobic_unique = hydrophobic_unique.reset_index(drop=True)
hydrophobic_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<hydrophobic_unique["Residue"].size:
    freq = np.sum((hydrophobic["Residue"]==hydrophobic_unique["Residue"][x]))/(hydrophobic["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"hydrophobic",'ResName':hydrophobic_unique["ResName"][x],'Residue':hydrophobic_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        hydrophobic_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("Hydrophobic interactions by Residue number")
hydrophobic_df=pd.DataFrame(hydrophobic_db)
hydrophobic_df=hydrophobic_df.loc[~(hydrophobic_df==0).all(axis=1)]
print(pd.DataFrame(hydrophobic_df))

#IONIC INTERACTIONS
ionic_unique=ionic.drop_duplicates(['Residue'])
ionic_unique = ionic_unique.reset_index(drop=True)
ionic_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<ionic_unique["Residue"].size:
    freq = np.sum((ionic["Residue"]==ionic_unique["Residue"][x]))/(ionic["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"ionic",'ResName':ionic_unique["ResName"][x],'Residue':ionic_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        ionic_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("Ionic interactions by Residue number")
ionic_df=pd.DataFrame(ionic_db)
ionic_df=ionic_df.loc[~(ionic_df==0).all(axis=1)]
print(pd.DataFrame(ionic_df))

#PI-PI INTERACTIONS
pipi_unique=pipi.drop_duplicates(['Residue'])
pipi_unique = pipi_unique.reset_index(drop=True)
pipi_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<pipi_unique["Residue"].size:
    freq = np.sum((pipi["Residue"]==pipi_unique["Residue"][x]))/(pipi["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"pi-pi",'ResName':pipi_unique["ResName"][x],'Residue':pipi_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        pipi_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("pi-pi interactions by Residue number")
pipi_df=pd.DataFrame(pipi_db)
pipi_df=pipi_df.loc[~(pipi_df==0).all(axis=1)]
print(pd.DataFrame(pipi_df))

#WATER INTERACTIONS
water_unique=water.drop_duplicates(['Residue'])
water_unique = water_unique.reset_index(drop=True)
water_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<water_unique["Residue"].size:
    freq = np.sum((water["Residue"]==water_unique["Residue"][x]))/(water["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"water",'ResName':water_unique["ResName"][x],'Residue':water_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        water_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("water-mediated interactions by Residue number")
water_df=pd.DataFrame(water_db)
water_df=water_df.loc[~(water_df==0).all(axis=1)]
print(pd.DataFrame(water_df))
# Out:
# hydrogen bond by Residue and AtomName number
#     Type ResName  Residue AtomName  Frequency
# 1  hbond     MET       87        H  59.833440
# 2  hbond     SER       88        H  83.920564
# 3  hbond     SER       88       HG  81.550288
# 4  hbond     THR       85        H  59.833440
# Hydrophobic interactions by Residue number
#           Type ResName  Residue  Frequency
# 1  hydrophobic     ILE       81  98.461538
# Ionic interactions by Residue number
# Empty DataFrame
# Columns: [Type, ResName, Residue, Frequency]
# Index: []
# pi-pi interactions by Residue number
# Empty DataFrame
# Columns: [Type, ResName, Residue, Frequency]
# Index: []
# water-mediated interactions by Residue number
#     Type ResName  Residue  Frequency
# 1  water     ASP       27  10.290987
# 2  water     GLY       83  39.460610
# 3  water     ILE       81  16.891412

# %%
#In case you want to have different styles : https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
frames = pd.concat([hbond_df,water_df,hydrophobic_df,ionic_df,pipi_df])
#frames.to_csv('interactions.tsv', sep = '\t')
print(frames)
frames.to_csv('interactions_{}.tsv'.format(name), sep='\t')
# Out:
#           Type ResName  Residue AtomName  Frequency
# 1        hbond     MET       87        H  59.833440
# 2        hbond     SER       88        H  83.920564
# 3        hbond     SER       88       HG  81.550288
# 4        hbond     THR       85        H  59.833440
# 1        water     ASP       27      NaN  10.290987
# 2        water     GLY       83      NaN  39.460610
# 3        water     ILE       81      NaN  16.891412
# 1  hydrophobic     ILE       81      NaN  98.461538

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
import scipy.stats as stats
import glob

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning) #this was relevant for the String-boolean Int-boolean comparison in the Residue vs Atom double filtering below (god I miss SQL...)

# %%
# My poor less fancy importing scheme for multiple files =P
wrkdir = 'C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Results' #You have to define where the folders and subfolder will be
os.chdir(wrkdir)
name="Tyr114_188" #change here the name of the system, so it can pick all the files automatically

#Those features are stratified with the number of residue only
hydrophobic=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Tyr114_188\\PL-Contacts_Hydrophobic.dat'.format(wrkdir, name), sep='\s+')
ionic=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Tyr114_188\\PL-Contacts_Ionic.dat'.format(wrkdir, name), sep='\s+')

#Those features need the number of residue and atom for proper separation
pipi=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Tyr114_188\\PL-Contacts_Pi-Pi.dat'.format(wrkdir, name), sep='\s+')
hbond=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Tyr114_188\\PL-Contacts_HBond.dat'.format(wrkdir, name), sep='\s+')
water=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Tyr114_188\\PL-Contacts_WaterBridge.dat'.format(wrkdir, name), sep='\s+')

# %%
#HYDROGEN BOND INTERACTIONS
hbond_unique=hbond.drop_duplicates(['Residue','AtomName'])
hbond_unique = hbond_unique.reset_index(drop=True)
hbond_db = [{'Type':0,'ResName':0,'Residue':0, 'AtomName':0,'Frequency':0}] #I setup an interaction Type variable for later help with the plotting
x=0
while x<hbond_unique["Residue"].size:
    
    freq = np.sum((hbond["Residue"]==hbond_unique["Residue"][x])|(hbond["AtomName"]==hbond_unique["AtomName"][x]))/(hbond["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"hbond",'ResName':hbond_unique["ResName"][x],'Residue':hbond_unique["Residue"][x],'AtomName':hbond_unique["AtomName"][x], 'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        hbond_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
    
print("hydrogen bond by Residue and AtomName number")
hbond_df=pd.DataFrame(hbond_db)
hbond_df=hbond_df.loc[~(hbond_df==0).all(axis=1)]
print(pd.DataFrame(hbond_df))

#HYDROPHOBIC INTERACTIONS DEFINITIONS
hydrophobic_unique=hydrophobic.drop_duplicates(['Residue'])
hydrophobic_unique = hydrophobic_unique.reset_index(drop=True)
hydrophobic_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<hydrophobic_unique["Residue"].size:
    freq = np.sum((hydrophobic["Residue"]==hydrophobic_unique["Residue"][x]))/(hydrophobic["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"hydrophobic",'ResName':hydrophobic_unique["ResName"][x],'Residue':hydrophobic_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        hydrophobic_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("Hydrophobic interactions by Residue number")
hydrophobic_df=pd.DataFrame(hydrophobic_db)
hydrophobic_df=hydrophobic_df.loc[~(hydrophobic_df==0).all(axis=1)]
print(pd.DataFrame(hydrophobic_df))

#IONIC INTERACTIONS
ionic_unique=ionic.drop_duplicates(['Residue'])
ionic_unique = ionic_unique.reset_index(drop=True)
ionic_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<ionic_unique["Residue"].size:
    freq = np.sum((ionic["Residue"]==ionic_unique["Residue"][x]))/(ionic["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"ionic",'ResName':ionic_unique["ResName"][x],'Residue':ionic_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        ionic_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("Ionic interactions by Residue number")
ionic_df=pd.DataFrame(ionic_db)
ionic_df=ionic_df.loc[~(ionic_df==0).all(axis=1)]
print(pd.DataFrame(ionic_df))

#PI-PI INTERACTIONS
pipi_unique=pipi.drop_duplicates(['Residue'])
pipi_unique = pipi_unique.reset_index(drop=True)
pipi_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<pipi_unique["Residue"].size:
    freq = np.sum((pipi["Residue"]==pipi_unique["Residue"][x]))/(pipi["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"pi-pi",'ResName':pipi_unique["ResName"][x],'Residue':pipi_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        pipi_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("pi-pi interactions by Residue number")
pipi_df=pd.DataFrame(pipi_db)
pipi_df=pipi_df.loc[~(pipi_df==0).all(axis=1)]
print(pd.DataFrame(pipi_df))

#WATER INTERACTIONS
water_unique=water.drop_duplicates(['Residue'])
water_unique = water_unique.reset_index(drop=True)
water_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<water_unique["Residue"].size:
    freq = np.sum((water["Residue"]==water_unique["Residue"][x]))/(water["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"water",'ResName':water_unique["ResName"][x],'Residue':water_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        water_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("water-mediated interactions by Residue number")
water_df=pd.DataFrame(water_db)
water_df=water_df.loc[~(water_df==0).all(axis=1)]
print(pd.DataFrame(water_df))
# Out:
# hydrogen bond by Residue and AtomName number
#     Type ResName  Residue AtomName  Frequency
# 1  hbond     ALA      228        H   98.04878
# Hydrophobic interactions by Residue number
#           Type ResName  Residue  Frequency
# 1  hydrophobic     MET      115  80.757098
# 2  hydrophobic     PHE      113  15.141956
# Ionic interactions by Residue number
# Empty DataFrame
# Columns: [Type, ResName, Residue, Frequency]
# Index: []
# pi-pi interactions by Residue number
#     Type ResName  Residue   Frequency
# 1  pi-pi     PHE      113  100.531915
# water-mediated interactions by Residue number
#     Type ResName  Residue  Frequency
# 1  water     GLU      234  43.059490
# 2  water     ALA      228  45.042493

# %%
#In case you want to have different styles : https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
frames = pd.concat([hbond_df,water_df,hydrophobic_df,ionic_df,pipi_df])
#frames.to_csv('interactions.tsv', sep = '\t')
print(frames)
frames.to_csv('interactions_{}.tsv'.format(name), sep='\t')
# Out:
#           Type ResName  Residue AtomName   Frequency
# 1        hbond     ALA      228        H   98.048780
# 1        water     GLU      234      NaN   43.059490
# 2        water     ALA      228      NaN   45.042493
# 1  hydrophobic     MET      115      NaN   80.757098
# 2  hydrophobic     PHE      113      NaN   15.141956
# 1        pi-pi     PHE      113      NaN  100.531915

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
import scipy.stats as stats
import glob

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning) #this was relevant for the String-boolean Int-boolean comparison in the Residue vs Atom double filtering below (god I miss SQL...)

# %%
# My poor less fancy importing scheme for multiple files =P
wrkdir = 'C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Results' #You have to define where the folders and subfolder will be
os.chdir(wrkdir)
name="Tyr114_189" #change here the name of the system, so it can pick all the files automatically

#Those features are stratified with the number of residue only
hydrophobic=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Tyr114_189\\PL-Contacts_Hydrophobic.dat'.format(wrkdir, name), sep='\s+')
ionic=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Tyr114_189\\PL-Contacts_Ionic.dat'.format(wrkdir, name), sep='\s+')

#Those features need the number of residue and atom for proper separation
pipi=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Tyr114_189\\PL-Contacts_Pi-Pi.dat'.format(wrkdir, name), sep='\s+')
hbond=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Tyr114_189\\PL-Contacts_HBond.dat'.format(wrkdir, name), sep='\s+')
water=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Tyr114_189\\PL-Contacts_WaterBridge.dat'.format(wrkdir, name), sep='\s+')

# %%
#HYDROGEN BOND INTERACTIONS
hbond_unique=hbond.drop_duplicates(['Residue','AtomName'])
hbond_unique = hbond_unique.reset_index(drop=True)
hbond_db = [{'Type':0,'ResName':0,'Residue':0, 'AtomName':0,'Frequency':0}] #I setup an interaction Type variable for later help with the plotting
x=0
while x<hbond_unique["Residue"].size:
    
    freq = np.sum((hbond["Residue"]==hbond_unique["Residue"][x])|(hbond["AtomName"]==hbond_unique["AtomName"][x]))/(hbond["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"hbond",'ResName':hbond_unique["ResName"][x],'Residue':hbond_unique["Residue"][x],'AtomName':hbond_unique["AtomName"][x], 'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        hbond_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
    
print("hydrogen bond by Residue and AtomName number")
hbond_df=pd.DataFrame(hbond_db)
hbond_df=hbond_df.loc[~(hbond_df==0).all(axis=1)]
print(pd.DataFrame(hbond_df))

#HYDROPHOBIC INTERACTIONS DEFINITIONS
hydrophobic_unique=hydrophobic.drop_duplicates(['Residue'])
hydrophobic_unique = hydrophobic_unique.reset_index(drop=True)
hydrophobic_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<hydrophobic_unique["Residue"].size:
    freq = np.sum((hydrophobic["Residue"]==hydrophobic_unique["Residue"][x]))/(hydrophobic["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"hydrophobic",'ResName':hydrophobic_unique["ResName"][x],'Residue':hydrophobic_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        hydrophobic_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("Hydrophobic interactions by Residue number")
hydrophobic_df=pd.DataFrame(hydrophobic_db)
hydrophobic_df=hydrophobic_df.loc[~(hydrophobic_df==0).all(axis=1)]
print(pd.DataFrame(hydrophobic_df))

#IONIC INTERACTIONS
ionic_unique=ionic.drop_duplicates(['Residue'])
ionic_unique = ionic_unique.reset_index(drop=True)
ionic_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<ionic_unique["Residue"].size:
    freq = np.sum((ionic["Residue"]==ionic_unique["Residue"][x]))/(ionic["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"ionic",'ResName':ionic_unique["ResName"][x],'Residue':ionic_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        ionic_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("Ionic interactions by Residue number")
ionic_df=pd.DataFrame(ionic_db)
ionic_df=ionic_df.loc[~(ionic_df==0).all(axis=1)]
print(pd.DataFrame(ionic_df))

#PI-PI INTERACTIONS
pipi_unique=pipi.drop_duplicates(['Residue'])
pipi_unique = pipi_unique.reset_index(drop=True)
pipi_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<pipi_unique["Residue"].size:
    freq = np.sum((pipi["Residue"]==pipi_unique["Residue"][x]))/(pipi["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"pi-pi",'ResName':pipi_unique["ResName"][x],'Residue':pipi_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        pipi_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("pi-pi interactions by Residue number")
pipi_df=pd.DataFrame(pipi_db)
pipi_df=pipi_df.loc[~(pipi_df==0).all(axis=1)]
print(pd.DataFrame(pipi_df))

#WATER INTERACTIONS
water_unique=water.drop_duplicates(['Residue'])
water_unique = water_unique.reset_index(drop=True)
water_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<water_unique["Residue"].size:
    freq = np.sum((water["Residue"]==water_unique["Residue"][x]))/(water["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"water",'ResName':water_unique["ResName"][x],'Residue':water_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        water_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("water-mediated interactions by Residue number")
water_df=pd.DataFrame(water_db)
water_df=water_df.loc[~(water_df==0).all(axis=1)]
print(pd.DataFrame(water_df))
# Out:
# hydrogen bond by Residue and AtomName number
#     Type ResName  Residue AtomName  Frequency
# 1  hbond     ALA      228        H  96.634615
# 2  hbond     ARG      161        H  96.634615
# 3  hbond     THR       85        H  96.634615
# 4  hbond     LEU       86        H  96.634615
# Hydrophobic interactions by Residue number
#           Type ResName  Residue  Frequency
# 1  hydrophobic     MET      115  80.912863
# 2  hydrophobic     PHE      113  15.352697
# Ionic interactions by Residue number
# Empty DataFrame
# Columns: [Type, ResName, Residue, Frequency]
# Index: []
# pi-pi interactions by Residue number
#     Type ResName  Residue  Frequency
# 1  pi-pi     PHE      113      100.0
# water-mediated interactions by Residue number
#     Type ResName  Residue  Frequency
# 1  water     ALA      228  46.827411
# 2  water     GLU      234  42.195431

# %%
#In case you want to have different styles : https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
frames = pd.concat([hbond_df,water_df,hydrophobic_df,ionic_df,pipi_df])
#frames.to_csv('interactions.tsv', sep = '\t')
print(frames)
frames.to_csv('interactions_{}.tsv'.format(name), sep='\t')
# Out:
#           Type ResName  Residue AtomName   Frequency
# 1        hbond     ALA      228        H   96.634615
# 2        hbond     ARG      161        H   96.634615
# 3        hbond     THR       85        H   96.634615
# 4        hbond     LEU       86        H   96.634615
# 1        water     ALA      228      NaN   46.827411
# 2        water     GLU      234      NaN   42.195431
# 1  hydrophobic     MET      115      NaN   80.912863
# 2  hydrophobic     PHE      113      NaN   15.352697
# 1        pi-pi     PHE      113      NaN  100.000000

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
import scipy.stats as stats
import glob

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning) #this was relevant for the String-boolean Int-boolean comparison in the Residue vs Atom double filtering below (god I miss SQL...)

# %%
# My poor less fancy importing scheme for multiple files =P
wrkdir = 'C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Results' #You have to define where the folders and subfolder will be
os.chdir(wrkdir)
name="Asn116_188" #change here the name of the system, so it can pick all the files automatically

#Those features are stratified with the number of residue only
hydrophobic=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Tyr116_188\\PL-Contacts_Hydrophobic.dat'.format(wrkdir, name), sep='\s+')
ionic=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Tyr116_188\\PL-Contacts_Ionic.dat'.format(wrkdir, name), sep='\s+')

#Those features need the number of residue and atom for proper separation
pipi=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Tyr116_188\\PL-Contacts_Pi-Pi.dat'.format(wrkdir, name), sep='\s+')
hbond=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Tyr116_188\\PL-Contacts_HBond.dat'.format(wrkdir, name), sep='\s+')
water=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Tyr116_188\\PL-Contacts_WaterBridge.dat'.format(wrkdir, name), sep='\s+')

# %%
#HYDROGEN BOND INTERACTIONS
hbond_unique=hbond.drop_duplicates(['Residue','AtomName'])
hbond_unique = hbond_unique.reset_index(drop=True)
hbond_db = [{'Type':0,'ResName':0,'Residue':0, 'AtomName':0,'Frequency':0}] #I setup an interaction Type variable for later help with the plotting
x=0
while x<hbond_unique["Residue"].size:
    
    freq = np.sum((hbond["Residue"]==hbond_unique["Residue"][x])|(hbond["AtomName"]==hbond_unique["AtomName"][x]))/(hbond["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"hbond",'ResName':hbond_unique["ResName"][x],'Residue':hbond_unique["Residue"][x],'AtomName':hbond_unique["AtomName"][x], 'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        hbond_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
    
print("hydrogen bond by Residue and AtomName number")
hbond_df=pd.DataFrame(hbond_db)
hbond_df=hbond_df.loc[~(hbond_df==0).all(axis=1)]
print(pd.DataFrame(hbond_df))

#HYDROPHOBIC INTERACTIONS DEFINITIONS
hydrophobic_unique=hydrophobic.drop_duplicates(['Residue'])
hydrophobic_unique = hydrophobic_unique.reset_index(drop=True)
hydrophobic_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<hydrophobic_unique["Residue"].size:
    freq = np.sum((hydrophobic["Residue"]==hydrophobic_unique["Residue"][x]))/(hydrophobic["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"hydrophobic",'ResName':hydrophobic_unique["ResName"][x],'Residue':hydrophobic_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        hydrophobic_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("Hydrophobic interactions by Residue number")
hydrophobic_df=pd.DataFrame(hydrophobic_db)
hydrophobic_df=hydrophobic_df.loc[~(hydrophobic_df==0).all(axis=1)]
print(pd.DataFrame(hydrophobic_df))

#IONIC INTERACTIONS
ionic_unique=ionic.drop_duplicates(['Residue'])
ionic_unique = ionic_unique.reset_index(drop=True)
ionic_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<ionic_unique["Residue"].size:
    freq = np.sum((ionic["Residue"]==ionic_unique["Residue"][x]))/(ionic["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"ionic",'ResName':ionic_unique["ResName"][x],'Residue':ionic_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        ionic_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("Ionic interactions by Residue number")
ionic_df=pd.DataFrame(ionic_db)
ionic_df=ionic_df.loc[~(ionic_df==0).all(axis=1)]
print(pd.DataFrame(ionic_df))

#PI-PI INTERACTIONS
pipi_unique=pipi.drop_duplicates(['Residue'])
pipi_unique = pipi_unique.reset_index(drop=True)
pipi_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<pipi_unique["Residue"].size:
    freq = np.sum((pipi["Residue"]==pipi_unique["Residue"][x]))/(pipi["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"pi-pi",'ResName':pipi_unique["ResName"][x],'Residue':pipi_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        pipi_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("pi-pi interactions by Residue number")
pipi_df=pd.DataFrame(pipi_db)
pipi_df=pipi_df.loc[~(pipi_df==0).all(axis=1)]
print(pd.DataFrame(pipi_df))

#WATER INTERACTIONS
water_unique=water.drop_duplicates(['Residue'])
water_unique = water_unique.reset_index(drop=True)
water_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<water_unique["Residue"].size:
    freq = np.sum((water["Residue"]==water_unique["Residue"][x]))/(water["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"water",'ResName':water_unique["ResName"][x],'Residue':water_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        water_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("water-mediated interactions by Residue number")
water_df=pd.DataFrame(water_db)
water_df=water_df.loc[~(water_df==0).all(axis=1)]
print(pd.DataFrame(water_df))
# Out:
# hydrogen bond by Residue and AtomName number
#      Type ResName  Residue AtomName  Frequency
# 1   hbond     GLN      226        O  96.411709
# 2   hbond     GLN      226        H  98.347498
# 3   hbond     PRO      160        O  48.016997
# 4   hbond     GLN      226      OE1  95.986780
# 5   hbond     GLY      104        O  48.016997
# 6   hbond     LYS      117        H  49.858357
# 7   hbond     ALA      171        O  48.016997
# 8   hbond     ASP      151        O  48.064212
# 9   hbond     SER       88        O  48.016997
# 10  hbond     GLY      221        H  49.858357
# 11  hbond     MET      219        O  48.016997
# 12  hbond     ASN       68        O  48.016997
# 13  hbond     GLY       21        O  48.016997
# 14  hbond     PRO       58        O  48.016997
# 15  hbond     LEU      239        O  48.016997
# 16  hbond     GLY      202        H  49.858357
# Hydrophobic interactions by Residue number
#           Type ResName  Residue  Frequency
# 1  hydrophobic     ILE      130  24.074074
# 2  hydrophobic     ILE      203  76.851852
# Ionic interactions by Residue number
# Empty DataFrame
# Columns: [Type, ResName, Residue, Frequency]
# Index: []
# pi-pi interactions by Residue number
# Empty DataFrame
# Columns: [Type, ResName, Residue, Frequency]
# Index: []
# water-mediated interactions by Residue number
#     Type ResName  Residue  Frequency
# 1  water     GLN      226  30.711139
# 2  water     LYS      117  42.290749
# 3  water     GLY      202  11.202014

# %%
#In case you want to have different styles : https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
frames = pd.concat([hbond_df,water_df,hydrophobic_df,ionic_df,pipi_df])
#frames.to_csv('interactions.tsv', sep = '\t')
print(frames)
frames.to_csv('interactions_{}.tsv'.format(name), sep='\t')
# Out:
#            Type ResName  Residue AtomName  Frequency
# 1         hbond     GLN      226        O  96.411709
# 2         hbond     GLN      226        H  98.347498
# 3         hbond     PRO      160        O  48.016997
# 4         hbond     GLN      226      OE1  95.986780
# 5         hbond     GLY      104        O  48.016997
# 6         hbond     LYS      117        H  49.858357
# 7         hbond     ALA      171        O  48.016997
# 8         hbond     ASP      151        O  48.064212
# 9         hbond     SER       88        O  48.016997
# 10        hbond     GLY      221        H  49.858357
# 11        hbond     MET      219        O  48.016997
# 12        hbond     ASN       68        O  48.016997
# 13        hbond     GLY       21        O  48.016997
# 14        hbond     PRO       58        O  48.016997
# 15        hbond     LEU      239        O  48.016997
# 16        hbond     GLY      202        H  49.858357
# 1         water     GLN      226      NaN  30.711139
# 2         water     LYS      117      NaN  42.290749
# 3         water     GLY      202      NaN  11.202014
# 1   hydrophobic     ILE      130      NaN  24.074074
# 2   hydrophobic     ILE      203      NaN  76.851852

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
import scipy.stats as stats
import glob

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning) #this was relevant for the String-boolean Int-boolean comparison in the Residue vs Atom double filtering below (god I miss SQL...)

# %%
# My poor less fancy importing scheme for multiple files =P
wrkdir = 'C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Results' #You have to define where the folders and subfolder will be
os.chdir(wrkdir)
name="Asn116_189" #change here the name of the system, so it can pick all the files automatically

#Those features are stratified with the number of residue only
hydrophobic=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Tyr116_189\\PL-Contacts_Hydrophobic.dat'.format(wrkdir, name), sep='\s+')
ionic=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Tyr116_189\\PL-Contacts_Ionic.dat'.format(wrkdir, name), sep='\s+')

#Those features need the number of residue and atom for proper separation
pipi=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Tyr116_189\\PL-Contacts_Pi-Pi.dat'.format(wrkdir, name), sep='\s+')
hbond=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Tyr116_189\\PL-Contacts_HBond.dat'.format(wrkdir, name), sep='\s+')
water=pd.read_table('C:\\Users\\greco\\OneDrive\\Área de Trabalho\\OneDrive\\Glaucio\\FBPase\\SID\\Tyr116_189\\PL-Contacts_WaterBridge.dat'.format(wrkdir, name), sep='\s+')

# %%
#HYDROGEN BOND INTERACTIONS
hbond_unique=hbond.drop_duplicates(['Residue','AtomName'])
hbond_unique = hbond_unique.reset_index(drop=True)
hbond_db = [{'Type':0,'ResName':0,'Residue':0, 'AtomName':0,'Frequency':0}] #I setup an interaction Type variable for later help with the plotting
x=0
while x<hbond_unique["Residue"].size:
    
    freq = np.sum((hbond["Residue"]==hbond_unique["Residue"][x])|(hbond["AtomName"]==hbond_unique["AtomName"][x]))/(hbond["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"hbond",'ResName':hbond_unique["ResName"][x],'Residue':hbond_unique["Residue"][x],'AtomName':hbond_unique["AtomName"][x], 'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        hbond_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
    
print("hydrogen bond by Residue and AtomName number")
hbond_df=pd.DataFrame(hbond_db)
hbond_df=hbond_df.loc[~(hbond_df==0).all(axis=1)]
print(pd.DataFrame(hbond_df))

#HYDROPHOBIC INTERACTIONS DEFINITIONS
hydrophobic_unique=hydrophobic.drop_duplicates(['Residue'])
hydrophobic_unique = hydrophobic_unique.reset_index(drop=True)
hydrophobic_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<hydrophobic_unique["Residue"].size:
    freq = np.sum((hydrophobic["Residue"]==hydrophobic_unique["Residue"][x]))/(hydrophobic["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"hydrophobic",'ResName':hydrophobic_unique["ResName"][x],'Residue':hydrophobic_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        hydrophobic_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("Hydrophobic interactions by Residue number")
hydrophobic_df=pd.DataFrame(hydrophobic_db)
hydrophobic_df=hydrophobic_df.loc[~(hydrophobic_df==0).all(axis=1)]
print(pd.DataFrame(hydrophobic_df))

#IONIC INTERACTIONS
ionic_unique=ionic.drop_duplicates(['Residue'])
ionic_unique = ionic_unique.reset_index(drop=True)
ionic_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<ionic_unique["Residue"].size:
    freq = np.sum((ionic["Residue"]==ionic_unique["Residue"][x]))/(ionic["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"ionic",'ResName':ionic_unique["ResName"][x],'Residue':ionic_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        ionic_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("Ionic interactions by Residue number")
ionic_df=pd.DataFrame(ionic_db)
ionic_df=ionic_df.loc[~(ionic_df==0).all(axis=1)]
print(pd.DataFrame(ionic_df))

#PI-PI INTERACTIONS
pipi_unique=pipi.drop_duplicates(['Residue'])
pipi_unique = pipi_unique.reset_index(drop=True)
pipi_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<pipi_unique["Residue"].size:
    freq = np.sum((pipi["Residue"]==pipi_unique["Residue"][x]))/(pipi["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"pi-pi",'ResName':pipi_unique["ResName"][x],'Residue':pipi_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        pipi_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("pi-pi interactions by Residue number")
pipi_df=pd.DataFrame(pipi_db)
pipi_df=pipi_df.loc[~(pipi_df==0).all(axis=1)]
print(pd.DataFrame(pipi_df))

#WATER INTERACTIONS
water_unique=water.drop_duplicates(['Residue'])
water_unique = water_unique.reset_index(drop=True)
water_db = [{'Type':0,'ResName':0,'Residue':0 , 'Frequency': 0}] #I setup an interaction Type variable for later help with the plotting

x=0 #resetting the counter!!
while x<water_unique["Residue"].size:
    freq = np.sum((water["Residue"]==water_unique["Residue"][x]))/(water["Residue"].size-1)*100
    if(freq>10): #Filtering to export only interactions with at least 10% frequency
        tmp_db= {'Type':"water",'ResName':water_unique["ResName"][x],'Residue':water_unique["Residue"][x],'Frequency':freq} #generates an entry in the dictionary with the residue number and Freq%
        water_db.append(tmp_db) #Appends the entry in the instanced dictionary
    x=x+1
print("water-mediated interactions by Residue number")
water_df=pd.DataFrame(water_db)
water_df=water_df.loc[~(water_df==0).all(axis=1)]
print(pd.DataFrame(water_df))
# Out:
# hydrogen bond by Residue and AtomName number
#      Type ResName  Residue AtomName  Frequency
# 1   hbond     GLN      226        O  96.236059
# 2   hbond     GLN      226        H  98.745353
# 3   hbond     LYS      117        H  49.674721
# 4   hbond     GLN      226      OE1  95.771375
# 5   hbond     ARG      161        O  47.211896
# 6   hbond     TB4      801        O  47.304833
# 7   hbond     LEU      272        O  47.211896
# 8   hbond     PRO      193        O  47.211896
# 9   hbond     LEU      178        O  47.211896
# 10  hbond     GLY      104        O  47.211896
# 11  hbond     SER      307        O  47.211896
# 12  hbond     ARG      230        O  47.211896
# Hydrophobic interactions by Residue number
#           Type ResName  Residue  Frequency
# 1  hydrophobic     ILE      203  60.273973
# 2  hydrophobic     ILE      130  41.095890
# Ionic interactions by Residue number
# Empty DataFrame
# Columns: [Type, ResName, Residue, Frequency]
# Index: []
# pi-pi interactions by Residue number
# Empty DataFrame
# Columns: [Type, ResName, Residue, Frequency]
# Index: []
# water-mediated interactions by Residue number
#     Type ResName  Residue  Frequency
# 1  water     GLN      226  40.591398
# 2  water     LYS      117  35.013441
# 3  water     GLY      202  11.559140

# %%
#In case you want to have different styles : https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
frames = pd.concat([hbond_df,water_df,hydrophobic_df,ionic_df,pipi_df])
#frames.to_csv('interactions.tsv', sep = '\t')
print(frames)
frames.to_csv('interactions_{}.tsv'.format(name), sep='\t')
# Out:
#            Type ResName  Residue AtomName  Frequency
# 1         hbond     GLN      226        O  96.236059
# 2         hbond     GLN      226        H  98.745353
# 3         hbond     LYS      117        H  49.674721
# 4         hbond     GLN      226      OE1  95.771375
# 5         hbond     ARG      161        O  47.211896
# 6         hbond     TB4      801        O  47.304833
# 7         hbond     LEU      272        O  47.211896
# 8         hbond     PRO      193        O  47.211896
# 9         hbond     LEU      178        O  47.211896
# 10        hbond     GLY      104        O  47.211896
# 11        hbond     SER      307        O  47.211896
# 12        hbond     ARG      230        O  47.211896
# 1         water     GLN      226      NaN  40.591398
# 2         water     LYS      117      NaN  35.013441
# 3         water     GLY      202      NaN  11.559140
# 1   hydrophobic     ILE      203      NaN  60.273973
# 2   hydrophobic     ILE      130      NaN  41.095890
