# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")

# %%
PCA_full=pd.read_csv("C:\\Users\\glauc\\OneDrive\\FBPase\\Results-gmf\\PCA\\PCA-result_proj.csv")
Apo=PCA_full.loc[1:201:1]
Substrate=PCA_full.loc[202:1206:1]
TB4=PCA_full.loc[1207:1312:1]
FBP=PCA_full.loc[1313:2318:1]
Sub=PCA_full.loc[2319:3123:1]
Dimer=PCA_full.loc[3124:4129:1]

#Apo - monomer
plot = sns.jointplot(x="PC_1", y="PC_2", data= Apo, color = "silver", kind="kde", fill=True)

#plot.ax_marg_x.set_xlim(-20, 20)
#plot.ax_marg_y.set_ylim(-40, 20)


fig1 = plt.gcf()
plt.rcParams['axes.labelsize'] = 24
plt.rcParams['axes.titlesize'] = 24
plt.show()
plt.draw()
fig1.savefig('Apo-mono.pdf', dpi=600)

# %%
PCA_full=pd.read_csv("C:\\Users\\glauc\\OneDrive\\FBPase\\Results-gmf\\PCA\\PCA-result_proj.csv")
Apo=PCA_full.loc[1:201:1]
Substrate=PCA_full.loc[202:1206:1]
TB4=PCA_full.loc[1207:1312:1]
FBP=PCA_full.loc[1313:2318:1]
Sub=PCA_full.loc[2319:3123:1]
Dimer=PCA_full.loc[3124:4129:1]

#Apo - monomer
plot = sns.jointplot(x="PC_1", y="PC_2", data= Substrate, color = "magenta", kind="kde", fill=True)

plot.ax_marg_x.set_xlim(-20, 20)
plot.ax_marg_y.set_ylim(-40, 20)


fig1 = plt.gcf()
plt.rcParams['axes.labelsize'] = 24
plt.rcParams['axes.titlesize'] = 24
plt.show()
plt.draw()
fig1.savefig('Substrate.pdf', dpi=600)

# %%
PCA_full=pd.read_csv("C:\\Users\\glauc\\OneDrive\\FBPase\\Results-gmf\\PCA\\PCA-result_proj.csv")
Apo=PCA_full.loc[1:201:1]
Substrate=PCA_full.loc[202:1206:1]
TB4=PCA_full.loc[1207:1312:1]
FBP=PCA_full.loc[1313:2318:1]
Sub=PCA_full.loc[2319:3123:1]
Dimer=PCA_full.loc[3124:4129:1]

#Apo - monomer
plot = sns.jointplot(x="PC_1", y="PC_2", data= TB4, color = "skyblue", kind="kde", fill=True)

plot.ax_marg_x.set_xlim(-20, 20)
plot.ax_marg_y.set_ylim(-40, 20)


fig1 = plt.gcf()
plt.rcParams['axes.labelsize'] = 24
plt.rcParams['axes.titlesize'] = 24
plt.show()
plt.draw()
fig1.savefig('TB4.pdf', dpi=600)

# %%
PCA_full=pd.read_csv("C:\\Users\\glauc\\OneDrive\\FBPase\\Results-gmf\\PCA\\PCA-result_proj.csv")
Apo=PCA_full.loc[1:201:1]
Substrate=PCA_full.loc[202:1206:1]
TB4=PCA_full.loc[1207:1312:1]
FBP=PCA_full.loc[1313:2318:1]
Sub=PCA_full.loc[2319:3123:1]
Dimer=PCA_full.loc[3124:4129:1]

#Apo - monomer
plot = sns.jointplot(x="PC_1", y="PC_2", data= FBP, color = "orange", kind="kde", fill=True)

plot.ax_marg_x.set_xlim(-20, 20)
plot.ax_marg_y.set_ylim(-40, 20)


fig1 = plt.gcf()
plt.rcParams['axes.labelsize'] = 24
plt.rcParams['axes.titlesize'] = 24
plt.show()
plt.draw()
fig1.savefig('FBP.pdf', dpi=600)

# %%
PCA_full=pd.read_csv("C:\\Users\\glauc\\OneDrive\\FBPase\\Results-gmf\\PCA\\PCA-result_proj.csv")
Apo=PCA_full.loc[1:201:1]
Substrate=PCA_full.loc[202:1206:1]
TB4=PCA_full.loc[1207:1312:1]
FBP=PCA_full.loc[1313:2318:1]
Sub=PCA_full.loc[2319:3123:1]
Dimer=PCA_full.loc[3124:4129:1]

#Apo - monomer
plot = sns.jointplot(x="PC_1", y="PC_2", data= Sub, color = "salmon", kind="kde", fill=True)

plot.ax_marg_x.set_xlim(-20, 20)
plot.ax_marg_y.set_ylim(-40, 20)


fig1 = plt.gcf()
plt.rcParams['axes.labelsize'] = 24
plt.rcParams['axes.titlesize'] = 24
plt.show()
plt.draw()
fig1.savefig('Sub.pdf', dpi=600)

# %%
PCA_full=pd.read_csv("C:\\Users\\glauc\\OneDrive\\FBPase\\Results-gmf\\PCA\\PCA-result_proj.csv")
Apo=PCA_full.loc[1:201:1]
Substrate=PCA_full.loc[202:1206:1]
TB4=PCA_full.loc[1207:1312:1]
FBP=PCA_full.loc[1313:2318:1]
Sub=PCA_full.loc[2319:3123:1]
Dimer=PCA_full.loc[3124:4129:1]

#Apo - monomer
plot = sns.jointplot(x="PC_1", y="PC_2", data= Dimer, color = "lightgreen", kind="kde", fill=True)

plot.ax_marg_x.set_xlim(-20, 20)
plot.ax_marg_y.set_ylim(-40, 20)


fig1 = plt.gcf()
plt.rcParams['axes.labelsize'] = 24
plt.rcParams['axes.titlesize'] = 24
plt.show()
plt.draw()
fig1.savefig('Dimer.pdf', dpi=600)
